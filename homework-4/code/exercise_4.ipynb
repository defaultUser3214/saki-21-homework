# %% [markdown]
# # SAKI Homework 4 SS21

# %% [markdown]
# ## Implemention of a reinforcement loearning based algorith for a warehouse organizing robot

# %% [markdown]
# ## Package import

# %%
import numpy as np
import pandas as pd
import csv
import itertools
import mdptoolbox
import os
import copy

# %% [markdown]
# ## Data loading

# %%
current_working_directory = os.getcwd()
path_to_warehouse_training_file = os.path.join(current_working_directory, "warehousetraining.txt")
path_to_warehouse_order_file = os.path.join(current_working_directory, 'warehouseorder.txt')
warehouse_training = pd.read_csv(path_to_warehouse_training_file, names=["action", "color"], delimiter="\t")
warehouse_order = pd.read_csv(path_to_warehouse_order_file, names=["action", "color"], delimiter="\t")

# %% [markdown]
# ## Exploration of the data set to examine the probabilities of the occurances of colors and actions

# %%
num_training_samples = len(warehouse_training)
probability_evaluation = warehouse_training.groupby(['action','color']).size().reset_index(name='num')
probability_evaluation['probability'] = probability_evaluation['num']/num_training_samples
probability_evaluation
# Out:
#     action  color   num  probability
# 0  restore   blue   995     0.121683
# 1  restore    red  2064     0.252415
# 2  restore  white  1029     0.125841
# 3    store   blue   995     0.121683
# 4    store    red  2064     0.252415
# 5    store  white  1030     0.125963

# %% [markdown]
# ## Definition of the 6 actions in our warehouse

# %% [markdown]
# ### Definition of actions
# We have three colors in our warehouse and two actions (store and restore).

# %%
list_of_actions = ['store_red', 'store_blue', 'store_white', 'restore_red','restore_blue', 'restore_white']

# %% [markdown]
# ### Definition of States

# %%
items = ['red', 'blue','white', 'empty']
state_matrix = list(itertools.product(items,items, items, items, list_of_actions))

# %%
state_matrix
# Out:
# [('red', 'red', 'red', 'red', 'store_red'),
#  ('red', 'red', 'red', 'red', 'store_blue'),
#  ('red', 'red', 'red', 'red', 'store_white'),
#  ('red', 'red', 'red', 'red', 'restore_red'),
#  ('red', 'red', 'red', 'red', 'restore_blue'),
#  ('red', 'red', 'red', 'red', 'restore_white'),
#  ('red', 'red', 'red', 'blue', 'store_red'),
#  ('red', 'red', 'red', 'blue', 'store_blue'),
#  ('red', 'red', 'red', 'blue', 'store_white'),
#  ('red', 'red', 'red', 'blue', 'restore_red'),
#  ('red', 'red', 'red', 'blue', 'restore_blue'),
#  ('red', 'red', 'red', 'blue', 'restore_white'),
#  ('red', 'red', 'red', 'white', 'store_red'),
#  ('red', 'red', 'red', 'white', 'store_blue'),
#  ('red', 'red', 'red', 'white', 'store_white'),
#  ('red', 'red', 'red', 'white', 'restore_red'),
#  ('red', 'red', 'red', 'white', 'restore_blue'),
#  ('red', 'red', 'red', 'white', 'restore_white'),
#  ('red', 'red', 'red', 'empty', 'store_red'),
#  ('red', 'red', 'red', 'empty', 'store_blue'),
#  ('red', 'red', 'red', 'empty', 'store_white'),
#  ('red', 'red', 'red', 'empty', 'restore_red'),
#  ('red', 'red', 'red', 'empty', 'restore_blue'),
#  ('red', 'red', 'red', 'empty', 'restore_white'),
#  ('red', 'red', 'blue', 'red', 'store_red'),
#  ('red', 'red', 'blue', 'red', 'store_blue'),
#  ('red', 'red', 'blue', 'red', 'store_white'),
#  ('red', 'red', 'blue', 'red', 'restore_red'),
#  ('red', 'red', 'blue', 'red', 'restore_blue'),
#  ('red', 'red', 'blue', 'red', 'restore_white'),
#  ('red', 'red', 'blue', 'blue', 'store_red'),
#  ('red', 'red', 'blue', 'blue', 'store_blue'),
#  ('red', 'red', 'blue', 'blue', 'store_white'),
#  ('red', 'red', 'blue', 'blue', 'restore_red'),
#  ('red', 'red', 'blue', 'blue', 'restore_blue'),
#  ('red', 'red', 'blue', 'blue', 'restore_white'),
#  ('red', 'red', 'blue', 'white', 'store_red'),
#  ('red', 'red', 'blue', 'white', 'store_blue'),
#  ('red', 'red', 'blue', 'white', 'store_white'),
#  ('red', 'red', 'blue', 'white', 'restore_red'),
#  ('red', 'red', 'blue', 'white', 'restore_blue'),
#  ('red', 'red', 'blue', 'white', 'restore_white'),
#  ('red', 'red', 'blue', 'empty', 'store_red'),
#  ('red', 'red', 'blue', 'empty', 'store_blue'),
#  ('red', 'red', 'blue', 'empty', 'store_white'),
#  ('red', 'red', 'blue', 'empty', 'restore_red'),
#  ('red', 'red', 'blue', 'empty', 'restore_blue'),
#  ('red', 'red', 'blue', 'empty', 'restore_white'),
#  ('red', 'red', 'white', 'red', 'store_red'),
#  ('red', 'red', 'white', 'red', 'store_blue'),
#  ('red', 'red', 'white', 'red', 'store_white'),
#  ('red', 'red', 'white', 'red', 'restore_red'),
#  ('red', 'red', 'white', 'red', 'restore_blue'),
#  ('red', 'red', 'white', 'red', 'restore_white'),
#  ('red', 'red', 'white', 'blue', 'store_red'),
#  ('red', 'red', 'white', 'blue', 'store_blue'),
#  ('red', 'red', 'white', 'blue', 'store_white'),
#  ('red', 'red', 'white', 'blue', 'restore_red'),
#  ('red', 'red', 'white', 'blue', 'restore_blue'),
#  ('red', 'red', 'white', 'blue', 'restore_white'),
#  ('red', 'red', 'white', 'white', 'store_red'),
#  ('red', 'red', 'white', 'white', 'store_blue'),
#  ('red', 'red', 'white', 'white', 'store_white'),
#  ('red', 'red', 'white', 'white', 'restore_red'),
#  ('red', 'red', 'white', 'white', 'restore_blue'),
#  ('red', 'red', 'white', 'white', 'restore_white'),
#  ('red', 'red', 'white', 'empty', 'store_red'),
#  ('red', 'red', 'white', 'empty', 'store_blue'),
#  ('red', 'red', 'white', 'empty', 'store_white'),
#  ('red', 'red', 'white', 'empty', 'restore_red'),
#  ('red', 'red', 'white', 'empty', 'restore_blue'),
#  ('red', 'red', 'white', 'empty', 'restore_white'),
#  ('red', 'red', 'empty', 'red', 'store_red'),
#  ('red', 'red', 'empty', 'red', 'store_blue'),
#  ('red', 'red', 'empty', 'red', 'store_white'),
#  ('red', 'red', 'empty', 'red', 'restore_red'),
#  ('red', 'red', 'empty', 'red', 'restore_blue'),
#  ('red', 'red', 'empty', 'red', 'restore_white'),
#  ('red', 'red', 'empty', 'blue', 'store_red'),
#  ('red', 'red', 'empty', 'blue', 'store_blue'),
#  ('red', 'red', 'empty', 'blue', 'store_white'),
#  ('red', 'red', 'empty', 'blue', 'restore_red'),
#  ('red', 'red', 'empty', 'blue', 'restore_blue'),
#  ('red', 'red', 'empty', 'blue', 'restore_white'),
#  ('red', 'red', 'empty', 'white', 'store_red'),
#  ('red', 'red', 'empty', 'white', 'store_blue'),
#  ('red', 'red', 'empty', 'white', 'store_white'),
#  ('red', 'red', 'empty', 'white', 'restore_red'),
#  ('red', 'red', 'empty', 'white', 'restore_blue'),
#  ('red', 'red', 'empty', 'white', 'restore_white'),
#  ('red', 'red', 'empty', 'empty', 'store_red'),
#  ('red', 'red', 'empty', 'empty', 'store_blue'),
#  ('red', 'red', 'empty', 'empty', 'store_white'),
#  ('red', 'red', 'empty', 'empty', 'restore_red'),
#  ('red', 'red', 'empty', 'empty', 'restore_blue'),
#  ('red', 'red', 'empty', 'empty', 'restore_white'),
#  ('red', 'blue', 'red', 'red', 'store_red'),
#  ('red', 'blue', 'red', 'red', 'store_blue'),
#  ('red', 'blue', 'red', 'red', 'store_white'),
#  ('red', 'blue', 'red', 'red', 'restore_red'),
#  ('red', 'blue', 'red', 'red', 'restore_blue'),
#  ('red', 'blue', 'red', 'red', 'restore_white'),
#  ('red', 'blue', 'red', 'blue', 'store_red'),
#  ('red', 'blue', 'red', 'blue', 'store_blue'),
#  ('red', 'blue', 'red', 'blue', 'store_white'),
#  ('red', 'blue', 'red', 'blue', 'restore_red'),
#  ('red', 'blue', 'red', 'blue', 'restore_blue'),
#  ('red', 'blue', 'red', 'blue', 'restore_white'),
#  ('red', 'blue', 'red', 'white', 'store_red'),
#  ('red', 'blue', 'red', 'white', 'store_blue'),
#  ('red', 'blue', 'red', 'white', 'store_white'),
#  ('red', 'blue', 'red', 'white', 'restore_red'),
#  ('red', 'blue', 'red', 'white', 'restore_blue'),
#  ('red', 'blue', 'red', 'white', 'restore_white'),
#  ('red', 'blue', 'red', 'empty', 'store_red'),
#  ('red', 'blue', 'red', 'empty', 'store_blue'),
#  ('red', 'blue', 'red', 'empty', 'store_white'),
#  ('red', 'blue', 'red', 'empty', 'restore_red'),
#  ('red', 'blue', 'red', 'empty', 'restore_blue'),
#  ('red', 'blue', 'red', 'empty', 'restore_white'),
#  ('red', 'blue', 'blue', 'red', 'store_red'),
#  ('red', 'blue', 'blue', 'red', 'store_blue'),
#  ('red', 'blue', 'blue', 'red', 'store_white'),
#  ('red', 'blue', 'blue', 'red', 'restore_red'),
#  ('red', 'blue', 'blue', 'red', 'restore_blue'),
#  ('red', 'blue', 'blue', 'red', 'restore_white'),
#  ('red', 'blue', 'blue', 'blue', 'store_red'),
#  ('red', 'blue', 'blue', 'blue', 'store_blue'),
#  ('red', 'blue', 'blue', 'blue', 'store_white'),
#  ('red', 'blue', 'blue', 'blue', 'restore_red'),
#  ('red', 'blue', 'blue', 'blue', 'restore_blue'),
#  ('red', 'blue', 'blue', 'blue', 'restore_white'),
#  ('red', 'blue', 'blue', 'white', 'store_red'),
#  ('red', 'blue', 'blue', 'white', 'store_blue'),
#  ('red', 'blue', 'blue', 'white', 'store_white'),
#  ('red', 'blue', 'blue', 'white', 'restore_red'),
#  ('red', 'blue', 'blue', 'white', 'restore_blue'),
#  ('red', 'blue', 'blue', 'white', 'restore_white'),
#  ('red', 'blue', 'blue', 'empty', 'store_red'),
#  ('red', 'blue', 'blue', 'empty', 'store_blue'),
#  ('red', 'blue', 'blue', 'empty', 'store_white'),
#  ('red', 'blue', 'blue', 'empty', 'restore_red'),
#  ('red', 'blue', 'blue', 'empty', 'restore_blue'),
#  ('red', 'blue', 'blue', 'empty', 'restore_white'),
#  ('red', 'blue', 'white', 'red', 'store_red'),
#  ('red', 'blue', 'white', 'red', 'store_blue'),
#  ('red', 'blue', 'white', 'red', 'store_white'),
#  ('red', 'blue', 'white', 'red', 'restore_red'),
#  ('red', 'blue', 'white', 'red', 'restore_blue'),
#  ('red', 'blue', 'white', 'red', 'restore_white'),
#  ('red', 'blue', 'white', 'blue', 'store_red'),
#  ('red', 'blue', 'white', 'blue', 'store_blue'),
#  ('red', 'blue', 'white', 'blue', 'store_white'),
#  ('red', 'blue', 'white', 'blue', 'restore_red'),
#  ('red', 'blue', 'white', 'blue', 'restore_blue'),
#  ('red', 'blue', 'white', 'blue', 'restore_white'),
#  ('red', 'blue', 'white', 'white', 'store_red'),
#  ('red', 'blue', 'white', 'white', 'store_blue'),
#  ('red', 'blue', 'white', 'white', 'store_white'),
#  ('red', 'blue', 'white', 'white', 'restore_red'),
#  ('red', 'blue', 'white', 'white', 'restore_blue'),
#  ('red', 'blue', 'white', 'white', 'restore_white'),
#  ('red', 'blue', 'white', 'empty', 'store_red'),
#  ('red', 'blue', 'white', 'empty', 'store_blue'),
#  ('red', 'blue', 'white', 'empty', 'store_white'),
#  ('red', 'blue', 'white', 'empty', 'restore_red'),
#  ('red', 'blue', 'white', 'empty', 'restore_blue'),
#  ('red', 'blue', 'white', 'empty', 'restore_white'),
#  ('red', 'blue', 'empty', 'red', 'store_red'),
#  ('red', 'blue', 'empty', 'red', 'store_blue'),
#  ('red', 'blue', 'empty', 'red', 'store_white'),
#  ('red', 'blue', 'empty', 'red', 'restore_red'),
#  ('red', 'blue', 'empty', 'red', 'restore_blue'),
#  ('red', 'blue', 'empty', 'red', 'restore_white'),
#  ('red', 'blue', 'empty', 'blue', 'store_red'),
#  ('red', 'blue', 'empty', 'blue', 'store_blue'),
#  ('red', 'blue', 'empty', 'blue', 'store_white'),
#  ('red', 'blue', 'empty', 'blue', 'restore_red'),
#  ('red', 'blue', 'empty', 'blue', 'restore_blue'),
#  ('red', 'blue', 'empty', 'blue', 'restore_white'),
#  ('red', 'blue', 'empty', 'white', 'store_red'),
#  ('red', 'blue', 'empty', 'white', 'store_blue'),
#  ('red', 'blue', 'empty', 'white', 'store_white'),
#  ('red', 'blue', 'empty', 'white', 'restore_red'),
#  ('red', 'blue', 'empty', 'white', 'restore_blue'),
#  ('red', 'blue', 'empty', 'white', 'restore_white'),
#  ('red', 'blue', 'empty', 'empty', 'store_red'),
#  ('red', 'blue', 'empty', 'empty', 'store_blue'),
#  ('red', 'blue', 'empty', 'empty', 'store_white'),
#  ('red', 'blue', 'empty', 'empty', 'restore_red'),
#  ('red', 'blue', 'empty', 'empty', 'restore_blue'),
#  ('red', 'blue', 'empty', 'empty', 'restore_white'),
#  ('red', 'white', 'red', 'red', 'store_red'),
#  ('red', 'white', 'red', 'red', 'store_blue'),
#  ('red', 'white', 'red', 'red', 'store_white'),
#  ('red', 'white', 'red', 'red', 'restore_red'),
#  ('red', 'white', 'red', 'red', 'restore_blue'),
#  ('red', 'white', 'red', 'red', 'restore_white'),
#  ('red', 'white', 'red', 'blue', 'store_red'),
#  ('red', 'white', 'red', 'blue', 'store_blue'),
#  ('red', 'white', 'red', 'blue', 'store_white'),
#  ('red', 'white', 'red', 'blue', 'restore_red'),
#  ('red', 'white', 'red', 'blue', 'restore_blue'),
#  ('red', 'white', 'red', 'blue', 'restore_white'),
#  ('red', 'white', 'red', 'white', 'store_red'),
#  ('red', 'white', 'red', 'white', 'store_blue'),
#  ('red', 'white', 'red', 'white', 'store_white'),
#  ('red', 'white', 'red', 'white', 'restore_red'),
#  ('red', 'white', 'red', 'white', 'restore_blue'),
#  ('red', 'white', 'red', 'white', 'restore_white'),
#  ('red', 'white', 'red', 'empty', 'store_red'),
#  ('red', 'white', 'red', 'empty', 'store_blue'),
#  ('red', 'white', 'red', 'empty', 'store_white'),
#  ('red', 'white', 'red', 'empty', 'restore_red'),
#  ('red', 'white', 'red', 'empty', 'restore_blue'),
#  ('red', 'white', 'red', 'empty', 'restore_white'),
#  ('red', 'white', 'blue', 'red', 'store_red'),
#  ('red', 'white', 'blue', 'red', 'store_blue'),
#  ('red', 'white', 'blue', 'red', 'store_white'),
#  ('red', 'white', 'blue', 'red', 'restore_red'),
#  ('red', 'white', 'blue', 'red', 'restore_blue'),
#  ('red', 'white', 'blue', 'red', 'restore_white'),
#  ('red', 'white', 'blue', 'blue', 'store_red'),
#  ('red', 'white', 'blue', 'blue', 'store_blue'),
#  ('red', 'white', 'blue', 'blue', 'store_white'),
#  ('red', 'white', 'blue', 'blue', 'restore_red'),
#  ('red', 'white', 'blue', 'blue', 'restore_blue'),
#  ('red', 'white', 'blue', 'blue', 'restore_white'),
#  ('red', 'white', 'blue', 'white', 'store_red'),
#  ('red', 'white', 'blue', 'white', 'store_blue'),
#  ('red', 'white', 'blue', 'white', 'store_white'),
#  ('red', 'white', 'blue', 'white', 'restore_red'),
#  ('red', 'white', 'blue', 'white', 'restore_blue'),
#  ('red', 'white', 'blue', 'white', 'restore_white'),
#  ('red', 'white', 'blue', 'empty', 'store_red'),
#  ('red', 'white', 'blue', 'empty', 'store_blue'),
#  ('red', 'white', 'blue', 'empty', 'store_white'),
#  ('red', 'white', 'blue', 'empty', 'restore_red'),
#  ('red', 'white', 'blue', 'empty', 'restore_blue'),
#  ('red', 'white', 'blue', 'empty', 'restore_white'),
#  ('red', 'white', 'white', 'red', 'store_red'),
#  ('red', 'white', 'white', 'red', 'store_blue'),
#  ('red', 'white', 'white', 'red', 'store_white'),
#  ('red', 'white', 'white', 'red', 'restore_red'),
#  ('red', 'white', 'white', 'red', 'restore_blue'),
#  ('red', 'white', 'white', 'red', 'restore_white'),
#  ('red', 'white', 'white', 'blue', 'store_red'),
#  ('red', 'white', 'white', 'blue', 'store_blue'),
#  ('red', 'white', 'white', 'blue', 'store_white'),
#  ('red', 'white', 'white', 'blue', 'restore_red'),
#  ('red', 'white', 'white', 'blue', 'restore_blue'),
#  ('red', 'white', 'white', 'blue', 'restore_white'),
#  ('red', 'white', 'white', 'white', 'store_red'),
#  ('red', 'white', 'white', 'white', 'store_blue'),
#  ('red', 'white', 'white', 'white', 'store_white'),
#  ('red', 'white', 'white', 'white', 'restore_red'),
#  ('red', 'white', 'white', 'white', 'restore_blue'),
#  ('red', 'white', 'white', 'white', 'restore_white'),
#  ('red', 'white', 'white', 'empty', 'store_red'),
#  ('red', 'white', 'white', 'empty', 'store_blue'),
#  ('red', 'white', 'white', 'empty', 'store_white'),
#  ('red', 'white', 'white', 'empty', 'restore_red'),
#  ('red', 'white', 'white', 'empty', 'restore_blue'),
#  ('red', 'white', 'white', 'empty', 'restore_white'),
#  ('red', 'white', 'empty', 'red', 'store_red'),
#  ('red', 'white', 'empty', 'red', 'store_blue'),
#  ('red', 'white', 'empty', 'red', 'store_white'),
#  ('red', 'white', 'empty', 'red', 'restore_red'),
#  ('red', 'white', 'empty', 'red', 'restore_blue'),
#  ('red', 'white', 'empty', 'red', 'restore_white'),
#  ('red', 'white', 'empty', 'blue', 'store_red'),
#  ('red', 'white', 'empty', 'blue', 'store_blue'),
#  ('red', 'white', 'empty', 'blue', 'store_white'),
#  ('red', 'white', 'empty', 'blue', 'restore_red'),
#  ('red', 'white', 'empty', 'blue', 'restore_blue'),
#  ('red', 'white', 'empty', 'blue', 'restore_white'),
#  ('red', 'white', 'empty', 'white', 'store_red'),
#  ('red', 'white', 'empty', 'white', 'store_blue'),
#  ('red', 'white', 'empty', 'white', 'store_white'),
#  ('red', 'white', 'empty', 'white', 'restore_red'),
#  ('red', 'white', 'empty', 'white', 'restore_blue'),
#  ('red', 'white', 'empty', 'white', 'restore_white'),
#  ('red', 'white', 'empty', 'empty', 'store_red'),
#  ('red', 'white', 'empty', 'empty', 'store_blue'),
#  ('red', 'white', 'empty', 'empty', 'store_white'),
#  ('red', 'white', 'empty', 'empty', 'restore_red'),
#  ('red', 'white', 'empty', 'empty', 'restore_blue'),
#  ('red', 'white', 'empty', 'empty', 'restore_white'),
#  ('red', 'empty', 'red', 'red', 'store_red'),
#  ('red', 'empty', 'red', 'red', 'store_blue'),
#  ('red', 'empty', 'red', 'red', 'store_white'),
#  ('red', 'empty', 'red', 'red', 'restore_red'),
#  ('red', 'empty', 'red', 'red', 'restore_blue'),
#  ('red', 'empty', 'red', 'red', 'restore_white'),
#  ('red', 'empty', 'red', 'blue', 'store_red'),
#  ('red', 'empty', 'red', 'blue', 'store_blue'),
#  ('red', 'empty', 'red', 'blue', 'store_white'),
#  ('red', 'empty', 'red', 'blue', 'restore_red'),
#  ('red', 'empty', 'red', 'blue', 'restore_blue'),
#  ('red', 'empty', 'red', 'blue', 'restore_white'),
#  ('red', 'empty', 'red', 'white', 'store_red'),
#  ('red', 'empty', 'red', 'white', 'store_blue'),
#  ('red', 'empty', 'red', 'white', 'store_white'),
#  ('red', 'empty', 'red', 'white', 'restore_red'),
#  ('red', 'empty', 'red', 'white', 'restore_blue'),
#  ('red', 'empty', 'red', 'white', 'restore_white'),
#  ('red', 'empty', 'red', 'empty', 'store_red'),
#  ('red', 'empty', 'red', 'empty', 'store_blue'),
#  ('red', 'empty', 'red', 'empty', 'store_white'),
#  ('red', 'empty', 'red', 'empty', 'restore_red'),
#  ('red', 'empty', 'red', 'empty', 'restore_blue'),
#  ('red', 'empty', 'red', 'empty', 'restore_white'),
#  ('red', 'empty', 'blue', 'red', 'store_red'),
#  ('red', 'empty', 'blue', 'red', 'store_blue'),
#  ('red', 'empty', 'blue', 'red', 'store_white'),
#  ('red', 'empty', 'blue', 'red', 'restore_red'),
#  ('red', 'empty', 'blue', 'red', 'restore_blue'),
#  ('red', 'empty', 'blue', 'red', 'restore_white'),
#  ('red', 'empty', 'blue', 'blue', 'store_red'),
#  ('red', 'empty', 'blue', 'blue', 'store_blue'),
#  ('red', 'empty', 'blue', 'blue', 'store_white'),
#  ('red', 'empty', 'blue', 'blue', 'restore_red'),
#  ('red', 'empty', 'blue', 'blue', 'restore_blue'),
#  ('red', 'empty', 'blue', 'blue', 'restore_white'),
#  ('red', 'empty', 'blue', 'white', 'store_red'),
#  ('red', 'empty', 'blue', 'white', 'store_blue'),
#  ('red', 'empty', 'blue', 'white', 'store_white'),
#  ('red', 'empty', 'blue', 'white', 'restore_red'),
#  ('red', 'empty', 'blue', 'white', 'restore_blue'),
#  ('red', 'empty', 'blue', 'white', 'restore_white'),
#  ('red', 'empty', 'blue', 'empty', 'store_red'),
#  ('red', 'empty', 'blue', 'empty', 'store_blue'),
#  ('red', 'empty', 'blue', 'empty', 'store_white'),
#  ('red', 'empty', 'blue', 'empty', 'restore_red'),
#  ('red', 'empty', 'blue', 'empty', 'restore_blue'),
#  ('red', 'empty', 'blue', 'empty', 'restore_white'),
#  ('red', 'empty', 'white', 'red', 'store_red'),
#  ('red', 'empty', 'white', 'red', 'store_blue'),
#  ('red', 'empty', 'white', 'red', 'store_white'),
#  ('red', 'empty', 'white', 'red', 'restore_red'),
#  ('red', 'empty', 'white', 'red', 'restore_blue'),
#  ('red', 'empty', 'white', 'red', 'restore_white'),
#  ('red', 'empty', 'white', 'blue', 'store_red'),
#  ('red', 'empty', 'white', 'blue', 'store_blue'),
#  ('red', 'empty', 'white', 'blue', 'store_white'),
#  ('red', 'empty', 'white', 'blue', 'restore_red'),
#  ('red', 'empty', 'white', 'blue', 'restore_blue'),
#  ('red', 'empty', 'white', 'blue', 'restore_white'),
#  ('red', 'empty', 'white', 'white', 'store_red'),
#  ('red', 'empty', 'white', 'white', 'store_blue'),
#  ('red', 'empty', 'white', 'white', 'store_white'),
#  ('red', 'empty', 'white', 'white', 'restore_red'),
#  ('red', 'empty', 'white', 'white', 'restore_blue'),
#  ('red', 'empty', 'white', 'white', 'restore_white'),
#  ('red', 'empty', 'white', 'empty', 'store_red'),
#  ('red', 'empty', 'white', 'empty', 'store_blue'),
#  ('red', 'empty', 'white', 'empty', 'store_white'),
#  ('red', 'empty', 'white', 'empty', 'restore_red'),
#  ('red', 'empty', 'white', 'empty', 'restore_blue'),
#  ('red', 'empty', 'white', 'empty', 'restore_white'),
#  ('red', 'empty', 'empty', 'red', 'store_red'),
#  ('red', 'empty', 'empty', 'red', 'store_blue'),
#  ('red', 'empty', 'empty', 'red', 'store_white'),
#  ('red', 'empty', 'empty', 'red', 'restore_red'),
#  ('red', 'empty', 'empty', 'red', 'restore_blue'),
#  ('red', 'empty', 'empty', 'red', 'restore_white'),
#  ('red', 'empty', 'empty', 'blue', 'store_red'),
#  ('red', 'empty', 'empty', 'blue', 'store_blue'),
#  ('red', 'empty', 'empty', 'blue', 'store_white'),
#  ('red', 'empty', 'empty', 'blue', 'restore_red'),
#  ('red', 'empty', 'empty', 'blue', 'restore_blue'),
#  ('red', 'empty', 'empty', 'blue', 'restore_white'),
#  ('red', 'empty', 'empty', 'white', 'store_red'),
#  ('red', 'empty', 'empty', 'white', 'store_blue'),
#  ('red', 'empty', 'empty', 'white', 'store_white'),
#  ('red', 'empty', 'empty', 'white', 'restore_red'),
#  ('red', 'empty', 'empty', 'white', 'restore_blue'),
#  ('red', 'empty', 'empty', 'white', 'restore_white'),
#  ('red', 'empty', 'empty', 'empty', 'store_red'),
#  ('red', 'empty', 'empty', 'empty', 'store_blue'),
#  ('red', 'empty', 'empty', 'empty', 'store_white'),
#  ('red', 'empty', 'empty', 'empty', 'restore_red'),
#  ('red', 'empty', 'empty', 'empty', 'restore_blue'),
#  ('red', 'empty', 'empty', 'empty', 'restore_white'),
#  ('blue', 'red', 'red', 'red', 'store_red'),
#  ('blue', 'red', 'red', 'red', 'store_blue'),
#  ('blue', 'red', 'red', 'red', 'store_white'),
#  ('blue', 'red', 'red', 'red', 'restore_red'),
#  ('blue', 'red', 'red', 'red', 'restore_blue'),
#  ('blue', 'red', 'red', 'red', 'restore_white'),
#  ('blue', 'red', 'red', 'blue', 'store_red'),
#  ('blue', 'red', 'red', 'blue', 'store_blue'),
#  ('blue', 'red', 'red', 'blue', 'store_white'),
#  ('blue', 'red', 'red', 'blue', 'restore_red'),
#  ('blue', 'red', 'red', 'blue', 'restore_blue'),
#  ('blue', 'red', 'red', 'blue', 'restore_white'),
#  ('blue', 'red', 'red', 'white', 'store_red'),
#  ('blue', 'red', 'red', 'white', 'store_blue'),
#  ('blue', 'red', 'red', 'white', 'store_white'),
#  ('blue', 'red', 'red', 'white', 'restore_red'),
#  ('blue', 'red', 'red', 'white', 'restore_blue'),
#  ('blue', 'red', 'red', 'white', 'restore_white'),
#  ('blue', 'red', 'red', 'empty', 'store_red'),
#  ('blue', 'red', 'red', 'empty', 'store_blue'),
#  ('blue', 'red', 'red', 'empty', 'store_white'),
#  ('blue', 'red', 'red', 'empty', 'restore_red'),
#  ('blue', 'red', 'red', 'empty', 'restore_blue'),
#  ('blue', 'red', 'red', 'empty', 'restore_white'),
#  ('blue', 'red', 'blue', 'red', 'store_red'),
#  ('blue', 'red', 'blue', 'red', 'store_blue'),
#  ('blue', 'red', 'blue', 'red', 'store_white'),
#  ('blue', 'red', 'blue', 'red', 'restore_red'),
#  ('blue', 'red', 'blue', 'red', 'restore_blue'),
#  ('blue', 'red', 'blue', 'red', 'restore_white'),
#  ('blue', 'red', 'blue', 'blue', 'store_red'),
#  ('blue', 'red', 'blue', 'blue', 'store_blue'),
#  ('blue', 'red', 'blue', 'blue', 'store_white'),
#  ('blue', 'red', 'blue', 'blue', 'restore_red'),
#  ('blue', 'red', 'blue', 'blue', 'restore_blue'),
#  ('blue', 'red', 'blue', 'blue', 'restore_white'),
#  ('blue', 'red', 'blue', 'white', 'store_red'),
#  ('blue', 'red', 'blue', 'white', 'store_blue'),
#  ('blue', 'red', 'blue', 'white', 'store_white'),
#  ('blue', 'red', 'blue', 'white', 'restore_red'),
#  ('blue', 'red', 'blue', 'white', 'restore_blue'),
#  ('blue', 'red', 'blue', 'white', 'restore_white'),
#  ('blue', 'red', 'blue', 'empty', 'store_red'),
#  ('blue', 'red', 'blue', 'empty', 'store_blue'),
#  ('blue', 'red', 'blue', 'empty', 'store_white'),
#  ('blue', 'red', 'blue', 'empty', 'restore_red'),
#  ('blue', 'red', 'blue', 'empty', 'restore_blue'),
#  ('blue', 'red', 'blue', 'empty', 'restore_white'),
#  ('blue', 'red', 'white', 'red', 'store_red'),
#  ('blue', 'red', 'white', 'red', 'store_blue'),
#  ('blue', 'red', 'white', 'red', 'store_white'),
#  ('blue', 'red', 'white', 'red', 'restore_red'),
#  ('blue', 'red', 'white', 'red', 'restore_blue'),
#  ('blue', 'red', 'white', 'red', 'restore_white'),
#  ('blue', 'red', 'white', 'blue', 'store_red'),
#  ('blue', 'red', 'white', 'blue', 'store_blue'),
#  ('blue', 'red', 'white', 'blue', 'store_white'),
#  ('blue', 'red', 'white', 'blue', 'restore_red'),
#  ('blue', 'red', 'white', 'blue', 'restore_blue'),
#  ('blue', 'red', 'white', 'blue', 'restore_white'),
#  ('blue', 'red', 'white', 'white', 'store_red'),
#  ('blue', 'red', 'white', 'white', 'store_blue'),
#  ('blue', 'red', 'white', 'white', 'store_white'),
#  ('blue', 'red', 'white', 'white', 'restore_red'),
#  ('blue', 'red', 'white', 'white', 'restore_blue'),
#  ('blue', 'red', 'white', 'white', 'restore_white'),
#  ('blue', 'red', 'white', 'empty', 'store_red'),
#  ('blue', 'red', 'white', 'empty', 'store_blue'),
#  ('blue', 'red', 'white', 'empty', 'store_white'),
#  ('blue', 'red', 'white', 'empty', 'restore_red'),
#  ('blue', 'red', 'white', 'empty', 'restore_blue'),
#  ('blue', 'red', 'white', 'empty', 'restore_white'),
#  ('blue', 'red', 'empty', 'red', 'store_red'),
#  ('blue', 'red', 'empty', 'red', 'store_blue'),
#  ('blue', 'red', 'empty', 'red', 'store_white'),
#  ('blue', 'red', 'empty', 'red', 'restore_red'),
#  ('blue', 'red', 'empty', 'red', 'restore_blue'),
#  ('blue', 'red', 'empty', 'red', 'restore_white'),
#  ('blue', 'red', 'empty', 'blue', 'store_red'),
#  ('blue', 'red', 'empty', 'blue', 'store_blue'),
#  ('blue', 'red', 'empty', 'blue', 'store_white'),
#  ('blue', 'red', 'empty', 'blue', 'restore_red'),
#  ('blue', 'red', 'empty', 'blue', 'restore_blue'),
#  ('blue', 'red', 'empty', 'blue', 'restore_white'),
#  ('blue', 'red', 'empty', 'white', 'store_red'),
#  ('blue', 'red', 'empty', 'white', 'store_blue'),
#  ('blue', 'red', 'empty', 'white', 'store_white'),
#  ('blue', 'red', 'empty', 'white', 'restore_red'),
#  ('blue', 'red', 'empty', 'white', 'restore_blue'),
#  ('blue', 'red', 'empty', 'white', 'restore_white'),
#  ('blue', 'red', 'empty', 'empty', 'store_red'),
#  ('blue', 'red', 'empty', 'empty', 'store_blue'),
#  ('blue', 'red', 'empty', 'empty', 'store_white'),
#  ('blue', 'red', 'empty', 'empty', 'restore_red'),
#  ('blue', 'red', 'empty', 'empty', 'restore_blue'),
#  ('blue', 'red', 'empty', 'empty', 'restore_white'),
#  ('blue', 'blue', 'red', 'red', 'store_red'),
#  ('blue', 'blue', 'red', 'red', 'store_blue'),
#  ('blue', 'blue', 'red', 'red', 'store_white'),
#  ('blue', 'blue', 'red', 'red', 'restore_red'),
#  ('blue', 'blue', 'red', 'red', 'restore_blue'),
#  ('blue', 'blue', 'red', 'red', 'restore_white'),
#  ('blue', 'blue', 'red', 'blue', 'store_red'),
#  ('blue', 'blue', 'red', 'blue', 'store_blue'),
#  ('blue', 'blue', 'red', 'blue', 'store_white'),
#  ('blue', 'blue', 'red', 'blue', 'restore_red'),
#  ('blue', 'blue', 'red', 'blue', 'restore_blue'),
#  ('blue', 'blue', 'red', 'blue', 'restore_white'),
#  ('blue', 'blue', 'red', 'white', 'store_red'),
#  ('blue', 'blue', 'red', 'white', 'store_blue'),
#  ('blue', 'blue', 'red', 'white', 'store_white'),
#  ('blue', 'blue', 'red', 'white', 'restore_red'),
#  ('blue', 'blue', 'red', 'white', 'restore_blue'),
#  ('blue', 'blue', 'red', 'white', 'restore_white'),
#  ('blue', 'blue', 'red', 'empty', 'store_red'),
#  ('blue', 'blue', 'red', 'empty', 'store_blue'),
#  ('blue', 'blue', 'red', 'empty', 'store_white'),
#  ('blue', 'blue', 'red', 'empty', 'restore_red'),
#  ('blue', 'blue', 'red', 'empty', 'restore_blue'),
#  ('blue', 'blue', 'red', 'empty', 'restore_white'),
#  ('blue', 'blue', 'blue', 'red', 'store_red'),
#  ('blue', 'blue', 'blue', 'red', 'store_blue'),
#  ('blue', 'blue', 'blue', 'red', 'store_white'),
#  ('blue', 'blue', 'blue', 'red', 'restore_red'),
#  ('blue', 'blue', 'blue', 'red', 'restore_blue'),
#  ('blue', 'blue', 'blue', 'red', 'restore_white'),
#  ('blue', 'blue', 'blue', 'blue', 'store_red'),
#  ('blue', 'blue', 'blue', 'blue', 'store_blue'),
#  ('blue', 'blue', 'blue', 'blue', 'store_white'),
#  ('blue', 'blue', 'blue', 'blue', 'restore_red'),
#  ('blue', 'blue', 'blue', 'blue', 'restore_blue'),
#  ('blue', 'blue', 'blue', 'blue', 'restore_white'),
#  ('blue', 'blue', 'blue', 'white', 'store_red'),
#  ('blue', 'blue', 'blue', 'white', 'store_blue'),
#  ('blue', 'blue', 'blue', 'white', 'store_white'),
#  ('blue', 'blue', 'blue', 'white', 'restore_red'),
#  ('blue', 'blue', 'blue', 'white', 'restore_blue'),
#  ('blue', 'blue', 'blue', 'white', 'restore_white'),
#  ('blue', 'blue', 'blue', 'empty', 'store_red'),
#  ('blue', 'blue', 'blue', 'empty', 'store_blue'),
#  ('blue', 'blue', 'blue', 'empty', 'store_white'),
#  ('blue', 'blue', 'blue', 'empty', 'restore_red'),
#  ('blue', 'blue', 'blue', 'empty', 'restore_blue'),
#  ('blue', 'blue', 'blue', 'empty', 'restore_white'),
#  ('blue', 'blue', 'white', 'red', 'store_red'),
#  ('blue', 'blue', 'white', 'red', 'store_blue'),
#  ('blue', 'blue', 'white', 'red', 'store_white'),
#  ('blue', 'blue', 'white', 'red', 'restore_red'),
#  ('blue', 'blue', 'white', 'red', 'restore_blue'),
#  ('blue', 'blue', 'white', 'red', 'restore_white'),
#  ('blue', 'blue', 'white', 'blue', 'store_red'),
#  ('blue', 'blue', 'white', 'blue', 'store_blue'),
#  ('blue', 'blue', 'white', 'blue', 'store_white'),
#  ('blue', 'blue', 'white', 'blue', 'restore_red'),
#  ('blue', 'blue', 'white', 'blue', 'restore_blue'),
#  ('blue', 'blue', 'white', 'blue', 'restore_white'),
#  ('blue', 'blue', 'white', 'white', 'store_red'),
#  ('blue', 'blue', 'white', 'white', 'store_blue'),
#  ('blue', 'blue', 'white', 'white', 'store_white'),
#  ('blue', 'blue', 'white', 'white', 'restore_red'),
#  ('blue', 'blue', 'white', 'white', 'restore_blue'),
#  ('blue', 'blue', 'white', 'white', 'restore_white'),
#  ('blue', 'blue', 'white', 'empty', 'store_red'),
#  ('blue', 'blue', 'white', 'empty', 'store_blue'),
#  ('blue', 'blue', 'white', 'empty', 'store_white'),
#  ('blue', 'blue', 'white', 'empty', 'restore_red'),
#  ('blue', 'blue', 'white', 'empty', 'restore_blue'),
#  ('blue', 'blue', 'white', 'empty', 'restore_white'),
#  ('blue', 'blue', 'empty', 'red', 'store_red'),
#  ('blue', 'blue', 'empty', 'red', 'store_blue'),
#  ('blue', 'blue', 'empty', 'red', 'store_white'),
#  ('blue', 'blue', 'empty', 'red', 'restore_red'),
#  ('blue', 'blue', 'empty', 'red', 'restore_blue'),
#  ('blue', 'blue', 'empty', 'red', 'restore_white'),
#  ('blue', 'blue', 'empty', 'blue', 'store_red'),
#  ('blue', 'blue', 'empty', 'blue', 'store_blue'),
#  ('blue', 'blue', 'empty', 'blue', 'store_white'),
#  ('blue', 'blue', 'empty', 'blue', 'restore_red'),
#  ('blue', 'blue', 'empty', 'blue', 'restore_blue'),
#  ('blue', 'blue', 'empty', 'blue', 'restore_white'),
#  ('blue', 'blue', 'empty', 'white', 'store_red'),
#  ('blue', 'blue', 'empty', 'white', 'store_blue'),
#  ('blue', 'blue', 'empty', 'white', 'store_white'),
#  ('blue', 'blue', 'empty', 'white', 'restore_red'),
#  ('blue', 'blue', 'empty', 'white', 'restore_blue'),
#  ('blue', 'blue', 'empty', 'white', 'restore_white'),
#  ('blue', 'blue', 'empty', 'empty', 'store_red'),
#  ('blue', 'blue', 'empty', 'empty', 'store_blue'),
#  ('blue', 'blue', 'empty', 'empty', 'store_white'),
#  ('blue', 'blue', 'empty', 'empty', 'restore_red'),
#  ('blue', 'blue', 'empty', 'empty', 'restore_blue'),
#  ('blue', 'blue', 'empty', 'empty', 'restore_white'),
#  ('blue', 'white', 'red', 'red', 'store_red'),
#  ('blue', 'white', 'red', 'red', 'store_blue'),
#  ('blue', 'white', 'red', 'red', 'store_white'),
#  ('blue', 'white', 'red', 'red', 'restore_red'),
#  ('blue', 'white', 'red', 'red', 'restore_blue'),
#  ('blue', 'white', 'red', 'red', 'restore_white'),
#  ('blue', 'white', 'red', 'blue', 'store_red'),
#  ('blue', 'white', 'red', 'blue', 'store_blue'),
#  ('blue', 'white', 'red', 'blue', 'store_white'),
#  ('blue', 'white', 'red', 'blue', 'restore_red'),
#  ('blue', 'white', 'red', 'blue', 'restore_blue'),
#  ('blue', 'white', 'red', 'blue', 'restore_white'),
#  ('blue', 'white', 'red', 'white', 'store_red'),
#  ('blue', 'white', 'red', 'white', 'store_blue'),
#  ('blue', 'white', 'red', 'white', 'store_white'),
#  ('blue', 'white', 'red', 'white', 'restore_red'),
#  ('blue', 'white', 'red', 'white', 'restore_blue'),
#  ('blue', 'white', 'red', 'white', 'restore_white'),
#  ('blue', 'white', 'red', 'empty', 'store_red'),
#  ('blue', 'white', 'red', 'empty', 'store_blue'),
#  ('blue', 'white', 'red', 'empty', 'store_white'),
#  ('blue', 'white', 'red', 'empty', 'restore_red'),
#  ('blue', 'white', 'red', 'empty', 'restore_blue'),
#  ('blue', 'white', 'red', 'empty', 'restore_white'),
#  ('blue', 'white', 'blue', 'red', 'store_red'),
#  ('blue', 'white', 'blue', 'red', 'store_blue'),
#  ('blue', 'white', 'blue', 'red', 'store_white'),
#  ('blue', 'white', 'blue', 'red', 'restore_red'),
#  ('blue', 'white', 'blue', 'red', 'restore_blue'),
#  ('blue', 'white', 'blue', 'red', 'restore_white'),
#  ('blue', 'white', 'blue', 'blue', 'store_red'),
#  ('blue', 'white', 'blue', 'blue', 'store_blue'),
#  ('blue', 'white', 'blue', 'blue', 'store_white'),
#  ('blue', 'white', 'blue', 'blue', 'restore_red'),
#  ('blue', 'white', 'blue', 'blue', 'restore_blue'),
#  ('blue', 'white', 'blue', 'blue', 'restore_white'),
#  ('blue', 'white', 'blue', 'white', 'store_red'),
#  ('blue', 'white', 'blue', 'white', 'store_blue'),
#  ('blue', 'white', 'blue', 'white', 'store_white'),
#  ('blue', 'white', 'blue', 'white', 'restore_red'),
#  ('blue', 'white', 'blue', 'white', 'restore_blue'),
#  ('blue', 'white', 'blue', 'white', 'restore_white'),
#  ('blue', 'white', 'blue', 'empty', 'store_red'),
#  ('blue', 'white', 'blue', 'empty', 'store_blue'),
#  ('blue', 'white', 'blue', 'empty', 'store_white'),
#  ('blue', 'white', 'blue', 'empty', 'restore_red'),
#  ('blue', 'white', 'blue', 'empty', 'restore_blue'),
#  ('blue', 'white', 'blue', 'empty', 'restore_white'),
#  ('blue', 'white', 'white', 'red', 'store_red'),
#  ('blue', 'white', 'white', 'red', 'store_blue'),
#  ('blue', 'white', 'white', 'red', 'store_white'),
#  ('blue', 'white', 'white', 'red', 'restore_red'),
#  ('blue', 'white', 'white', 'red', 'restore_blue'),
#  ('blue', 'white', 'white', 'red', 'restore_white'),
#  ('blue', 'white', 'white', 'blue', 'store_red'),
#  ('blue', 'white', 'white', 'blue', 'store_blue'),
#  ('blue', 'white', 'white', 'blue', 'store_white'),
#  ('blue', 'white', 'white', 'blue', 'restore_red'),
#  ('blue', 'white', 'white', 'blue', 'restore_blue'),
#  ('blue', 'white', 'white', 'blue', 'restore_white'),
#  ('blue', 'white', 'white', 'white', 'store_red'),
#  ('blue', 'white', 'white', 'white', 'store_blue'),
#  ('blue', 'white', 'white', 'white', 'store_white'),
#  ('blue', 'white', 'white', 'white', 'restore_red'),
#  ('blue', 'white', 'white', 'white', 'restore_blue'),
#  ('blue', 'white', 'white', 'white', 'restore_white'),
#  ('blue', 'white', 'white', 'empty', 'store_red'),
#  ('blue', 'white', 'white', 'empty', 'store_blue'),
#  ('blue', 'white', 'white', 'empty', 'store_white'),
#  ('blue', 'white', 'white', 'empty', 'restore_red'),
#  ('blue', 'white', 'white', 'empty', 'restore_blue'),
#  ('blue', 'white', 'white', 'empty', 'restore_white'),
#  ('blue', 'white', 'empty', 'red', 'store_red'),
#  ('blue', 'white', 'empty', 'red', 'store_blue'),
#  ('blue', 'white', 'empty', 'red', 'store_white'),
#  ('blue', 'white', 'empty', 'red', 'restore_red'),
#  ('blue', 'white', 'empty', 'red', 'restore_blue'),
#  ('blue', 'white', 'empty', 'red', 'restore_white'),
#  ('blue', 'white', 'empty', 'blue', 'store_red'),
#  ('blue', 'white', 'empty', 'blue', 'store_blue'),
#  ('blue', 'white', 'empty', 'blue', 'store_white'),
#  ('blue', 'white', 'empty', 'blue', 'restore_red'),
#  ('blue', 'white', 'empty', 'blue', 'restore_blue'),
#  ('blue', 'white', 'empty', 'blue', 'restore_white'),
#  ('blue', 'white', 'empty', 'white', 'store_red'),
#  ('blue', 'white', 'empty', 'white', 'store_blue'),
#  ('blue', 'white', 'empty', 'white', 'store_white'),
#  ('blue', 'white', 'empty', 'white', 'restore_red'),
#  ('blue', 'white', 'empty', 'white', 'restore_blue'),
#  ('blue', 'white', 'empty', 'white', 'restore_white'),
#  ('blue', 'white', 'empty', 'empty', 'store_red'),
#  ('blue', 'white', 'empty', 'empty', 'store_blue'),
#  ('blue', 'white', 'empty', 'empty', 'store_white'),
#  ('blue', 'white', 'empty', 'empty', 'restore_red'),
#  ('blue', 'white', 'empty', 'empty', 'restore_blue'),
#  ('blue', 'white', 'empty', 'empty', 'restore_white'),
#  ('blue', 'empty', 'red', 'red', 'store_red'),
#  ('blue', 'empty', 'red', 'red', 'store_blue'),
#  ('blue', 'empty', 'red', 'red', 'store_white'),
#  ('blue', 'empty', 'red', 'red', 'restore_red'),
#  ('blue', 'empty', 'red', 'red', 'restore_blue'),
#  ('blue', 'empty', 'red', 'red', 'restore_white'),
#  ('blue', 'empty', 'red', 'blue', 'store_red'),
#  ('blue', 'empty', 'red', 'blue', 'store_blue'),
#  ('blue', 'empty', 'red', 'blue', 'store_white'),
#  ('blue', 'empty', 'red', 'blue', 'restore_red'),
#  ('blue', 'empty', 'red', 'blue', 'restore_blue'),
#  ('blue', 'empty', 'red', 'blue', 'restore_white'),
#  ('blue', 'empty', 'red', 'white', 'store_red'),
#  ('blue', 'empty', 'red', 'white', 'store_blue'),
#  ('blue', 'empty', 'red', 'white', 'store_white'),
#  ('blue', 'empty', 'red', 'white', 'restore_red'),
#  ('blue', 'empty', 'red', 'white', 'restore_blue'),
#  ('blue', 'empty', 'red', 'white', 'restore_white'),
#  ('blue', 'empty', 'red', 'empty', 'store_red'),
#  ('blue', 'empty', 'red', 'empty', 'store_blue'),
#  ('blue', 'empty', 'red', 'empty', 'store_white'),
#  ('blue', 'empty', 'red', 'empty', 'restore_red'),
#  ('blue', 'empty', 'red', 'empty', 'restore_blue'),
#  ('blue', 'empty', 'red', 'empty', 'restore_white'),
#  ('blue', 'empty', 'blue', 'red', 'store_red'),
#  ('blue', 'empty', 'blue', 'red', 'store_blue'),
#  ('blue', 'empty', 'blue', 'red', 'store_white'),
#  ('blue', 'empty', 'blue', 'red', 'restore_red'),
#  ('blue', 'empty', 'blue', 'red', 'restore_blue'),
#  ('blue', 'empty', 'blue', 'red', 'restore_white'),
#  ('blue', 'empty', 'blue', 'blue', 'store_red'),
#  ('blue', 'empty', 'blue', 'blue', 'store_blue'),
#  ('blue', 'empty', 'blue', 'blue', 'store_white'),
#  ('blue', 'empty', 'blue', 'blue', 'restore_red'),
#  ('blue', 'empty', 'blue', 'blue', 'restore_blue'),
#  ('blue', 'empty', 'blue', 'blue', 'restore_white'),
#  ('blue', 'empty', 'blue', 'white', 'store_red'),
#  ('blue', 'empty', 'blue', 'white', 'store_blue'),
#  ('blue', 'empty', 'blue', 'white', 'store_white'),
#  ('blue', 'empty', 'blue', 'white', 'restore_red'),
#  ('blue', 'empty', 'blue', 'white', 'restore_blue'),
#  ('blue', 'empty', 'blue', 'white', 'restore_white'),
#  ('blue', 'empty', 'blue', 'empty', 'store_red'),
#  ('blue', 'empty', 'blue', 'empty', 'store_blue'),
#  ('blue', 'empty', 'blue', 'empty', 'store_white'),
#  ('blue', 'empty', 'blue', 'empty', 'restore_red'),
#  ('blue', 'empty', 'blue', 'empty', 'restore_blue'),
#  ('blue', 'empty', 'blue', 'empty', 'restore_white'),
#  ('blue', 'empty', 'white', 'red', 'store_red'),
#  ('blue', 'empty', 'white', 'red', 'store_blue'),
#  ('blue', 'empty', 'white', 'red', 'store_white'),
#  ('blue', 'empty', 'white', 'red', 'restore_red'),
#  ('blue', 'empty', 'white', 'red', 'restore_blue'),
#  ('blue', 'empty', 'white', 'red', 'restore_white'),
#  ('blue', 'empty', 'white', 'blue', 'store_red'),
#  ('blue', 'empty', 'white', 'blue', 'store_blue'),
#  ('blue', 'empty', 'white', 'blue', 'store_white'),
#  ('blue', 'empty', 'white', 'blue', 'restore_red'),
#  ('blue', 'empty', 'white', 'blue', 'restore_blue'),
#  ('blue', 'empty', 'white', 'blue', 'restore_white'),
#  ('blue', 'empty', 'white', 'white', 'store_red'),
#  ('blue', 'empty', 'white', 'white', 'store_blue'),
#  ('blue', 'empty', 'white', 'white', 'store_white'),
#  ('blue', 'empty', 'white', 'white', 'restore_red'),
#  ('blue', 'empty', 'white', 'white', 'restore_blue'),
#  ('blue', 'empty', 'white', 'white', 'restore_white'),
#  ('blue', 'empty', 'white', 'empty', 'store_red'),
#  ('blue', 'empty', 'white', 'empty', 'store_blue'),
#  ('blue', 'empty', 'white', 'empty', 'store_white'),
#  ('blue', 'empty', 'white', 'empty', 'restore_red'),
#  ('blue', 'empty', 'white', 'empty', 'restore_blue'),
#  ('blue', 'empty', 'white', 'empty', 'restore_white'),
#  ('blue', 'empty', 'empty', 'red', 'store_red'),
#  ('blue', 'empty', 'empty', 'red', 'store_blue'),
#  ('blue', 'empty', 'empty', 'red', 'store_white'),
#  ('blue', 'empty', 'empty', 'red', 'restore_red'),
#  ('blue', 'empty', 'empty', 'red', 'restore_blue'),
#  ('blue', 'empty', 'empty', 'red', 'restore_white'),
#  ('blue', 'empty', 'empty', 'blue', 'store_red'),
#  ('blue', 'empty', 'empty', 'blue', 'store_blue'),
#  ('blue', 'empty', 'empty', 'blue', 'store_white'),
#  ('blue', 'empty', 'empty', 'blue', 'restore_red'),
#  ('blue', 'empty', 'empty', 'blue', 'restore_blue'),
#  ('blue', 'empty', 'empty', 'blue', 'restore_white'),
#  ('blue', 'empty', 'empty', 'white', 'store_red'),
#  ('blue', 'empty', 'empty', 'white', 'store_blue'),
#  ('blue', 'empty', 'empty', 'white', 'store_white'),
#  ('blue', 'empty', 'empty', 'white', 'restore_red'),
#  ('blue', 'empty', 'empty', 'white', 'restore_blue'),
#  ('blue', 'empty', 'empty', 'white', 'restore_white'),
#  ('blue', 'empty', 'empty', 'empty', 'store_red'),
#  ('blue', 'empty', 'empty', 'empty', 'store_blue'),
#  ('blue', 'empty', 'empty', 'empty', 'store_white'),
#  ('blue', 'empty', 'empty', 'empty', 'restore_red'),
#  ('blue', 'empty', 'empty', 'empty', 'restore_blue'),
#  ('blue', 'empty', 'empty', 'empty', 'restore_white'),
#  ('white', 'red', 'red', 'red', 'store_red'),
#  ('white', 'red', 'red', 'red', 'store_blue'),
#  ('white', 'red', 'red', 'red', 'store_white'),
#  ('white', 'red', 'red', 'red', 'restore_red'),
#  ('white', 'red', 'red', 'red', 'restore_blue'),
#  ('white', 'red', 'red', 'red', 'restore_white'),
#  ('white', 'red', 'red', 'blue', 'store_red'),
#  ('white', 'red', 'red', 'blue', 'store_blue'),
#  ('white', 'red', 'red', 'blue', 'store_white'),
#  ('white', 'red', 'red', 'blue', 'restore_red'),
#  ('white', 'red', 'red', 'blue', 'restore_blue'),
#  ('white', 'red', 'red', 'blue', 'restore_white'),
#  ('white', 'red', 'red', 'white', 'store_red'),
#  ('white', 'red', 'red', 'white', 'store_blue'),
#  ('white', 'red', 'red', 'white', 'store_white'),
#  ('white', 'red', 'red', 'white', 'restore_red'),
#  ('white', 'red', 'red', 'white', 'restore_blue'),
#  ('white', 'red', 'red', 'white', 'restore_white'),
#  ('white', 'red', 'red', 'empty', 'store_red'),
#  ('white', 'red', 'red', 'empty', 'store_blue'),
#  ('white', 'red', 'red', 'empty', 'store_white'),
#  ('white', 'red', 'red', 'empty', 'restore_red'),
#  ('white', 'red', 'red', 'empty', 'restore_blue'),
#  ('white', 'red', 'red', 'empty', 'restore_white'),
#  ('white', 'red', 'blue', 'red', 'store_red'),
#  ('white', 'red', 'blue', 'red', 'store_blue'),
#  ('white', 'red', 'blue', 'red', 'store_white'),
#  ('white', 'red', 'blue', 'red', 'restore_red'),
#  ('white', 'red', 'blue', 'red', 'restore_blue'),
#  ('white', 'red', 'blue', 'red', 'restore_white'),
#  ('white', 'red', 'blue', 'blue', 'store_red'),
#  ('white', 'red', 'blue', 'blue', 'store_blue'),
#  ('white', 'red', 'blue', 'blue', 'store_white'),
#  ('white', 'red', 'blue', 'blue', 'restore_red'),
#  ('white', 'red', 'blue', 'blue', 'restore_blue'),
#  ('white', 'red', 'blue', 'blue', 'restore_white'),
#  ('white', 'red', 'blue', 'white', 'store_red'),
#  ('white', 'red', 'blue', 'white', 'store_blue'),
#  ('white', 'red', 'blue', 'white', 'store_white'),
#  ('white', 'red', 'blue', 'white', 'restore_red'),
#  ('white', 'red', 'blue', 'white', 'restore_blue'),
#  ('white', 'red', 'blue', 'white', 'restore_white'),
#  ('white', 'red', 'blue', 'empty', 'store_red'),
#  ('white', 'red', 'blue', 'empty', 'store_blue'),
#  ('white', 'red', 'blue', 'empty', 'store_white'),
#  ('white', 'red', 'blue', 'empty', 'restore_red'),
#  ('white', 'red', 'blue', 'empty', 'restore_blue'),
#  ('white', 'red', 'blue', 'empty', 'restore_white'),
#  ('white', 'red', 'white', 'red', 'store_red'),
#  ('white', 'red', 'white', 'red', 'store_blue'),
#  ('white', 'red', 'white', 'red', 'store_white'),
#  ('white', 'red', 'white', 'red', 'restore_red'),
#  ('white', 'red', 'white', 'red', 'restore_blue'),
#  ('white', 'red', 'white', 'red', 'restore_white'),
#  ('white', 'red', 'white', 'blue', 'store_red'),
#  ('white', 'red', 'white', 'blue', 'store_blue'),
#  ('white', 'red', 'white', 'blue', 'store_white'),
#  ('white', 'red', 'white', 'blue', 'restore_red'),
#  ('white', 'red', 'white', 'blue', 'restore_blue'),
#  ('white', 'red', 'white', 'blue', 'restore_white'),
#  ('white', 'red', 'white', 'white', 'store_red'),
#  ('white', 'red', 'white', 'white', 'store_blue'),
#  ('white', 'red', 'white', 'white', 'store_white'),
#  ('white', 'red', 'white', 'white', 'restore_red'),
#  ('white', 'red', 'white', 'white', 'restore_blue'),
#  ('white', 'red', 'white', 'white', 'restore_white'),
#  ('white', 'red', 'white', 'empty', 'store_red'),
#  ('white', 'red', 'white', 'empty', 'store_blue'),
#  ('white', 'red', 'white', 'empty', 'store_white'),
#  ('white', 'red', 'white', 'empty', 'restore_red'),
#  ('white', 'red', 'white', 'empty', 'restore_blue'),
#  ('white', 'red', 'white', 'empty', 'restore_white'),
#  ('white', 'red', 'empty', 'red', 'store_red'),
#  ('white', 'red', 'empty', 'red', 'store_blue'),
#  ('white', 'red', 'empty', 'red', 'store_white'),
#  ('white', 'red', 'empty', 'red', 'restore_red'),
#  ('white', 'red', 'empty', 'red', 'restore_blue'),
#  ('white', 'red', 'empty', 'red', 'restore_white'),
#  ('white', 'red', 'empty', 'blue', 'store_red'),
#  ('white', 'red', 'empty', 'blue', 'store_blue'),
#  ('white', 'red', 'empty', 'blue', 'store_white'),
#  ('white', 'red', 'empty', 'blue', 'restore_red'),
#  ('white', 'red', 'empty', 'blue', 'restore_blue'),
#  ('white', 'red', 'empty', 'blue', 'restore_white'),
#  ('white', 'red', 'empty', 'white', 'store_red'),
#  ('white', 'red', 'empty', 'white', 'store_blue'),
#  ('white', 'red', 'empty', 'white', 'store_white'),
#  ('white', 'red', 'empty', 'white', 'restore_red'),
#  ('white', 'red', 'empty', 'white', 'restore_blue'),
#  ('white', 'red', 'empty', 'white', 'restore_white'),
#  ('white', 'red', 'empty', 'empty', 'store_red'),
#  ('white', 'red', 'empty', 'empty', 'store_blue'),
#  ('white', 'red', 'empty', 'empty', 'store_white'),
#  ('white', 'red', 'empty', 'empty', 'restore_red'),
#  ('white', 'red', 'empty', 'empty', 'restore_blue'),
#  ('white', 'red', 'empty', 'empty', 'restore_white'),
#  ('white', 'blue', 'red', 'red', 'store_red'),
#  ('white', 'blue', 'red', 'red', 'store_blue'),
#  ('white', 'blue', 'red', 'red', 'store_white'),
#  ('white', 'blue', 'red', 'red', 'restore_red'),
#  ('white', 'blue', 'red', 'red', 'restore_blue'),
#  ('white', 'blue', 'red', 'red', 'restore_white'),
#  ('white', 'blue', 'red', 'blue', 'store_red'),
#  ('white', 'blue', 'red', 'blue', 'store_blue'),
#  ('white', 'blue', 'red', 'blue', 'store_white'),
#  ('white', 'blue', 'red', 'blue', 'restore_red'),
#  ('white', 'blue', 'red', 'blue', 'restore_blue'),
#  ('white', 'blue', 'red', 'blue', 'restore_white'),
#  ('white', 'blue', 'red', 'white', 'store_red'),
#  ('white', 'blue', 'red', 'white', 'store_blue'),
#  ('white', 'blue', 'red', 'white', 'store_white'),
#  ('white', 'blue', 'red', 'white', 'restore_red'),
#  ('white', 'blue', 'red', 'white', 'restore_blue'),
#  ('white', 'blue', 'red', 'white', 'restore_white'),
#  ('white', 'blue', 'red', 'empty', 'store_red'),
#  ('white', 'blue', 'red', 'empty', 'store_blue'),
#  ('white', 'blue', 'red', 'empty', 'store_white'),
#  ('white', 'blue', 'red', 'empty', 'restore_red'),
#  ('white', 'blue', 'red', 'empty', 'restore_blue'),
#  ('white', 'blue', 'red', 'empty', 'restore_white'),
#  ('white', 'blue', 'blue', 'red', 'store_red'),
#  ('white', 'blue', 'blue', 'red', 'store_blue'),
#  ('white', 'blue', 'blue', 'red', 'store_white'),
#  ('white', 'blue', 'blue', 'red', 'restore_red'),
#  ('white', 'blue', 'blue', 'red', 'restore_blue'),
#  ('white', 'blue', 'blue', 'red', 'restore_white'),
#  ('white', 'blue', 'blue', 'blue', 'store_red'),
#  ('white', 'blue', 'blue', 'blue', 'store_blue'),
#  ('white', 'blue', 'blue', 'blue', 'store_white'),
#  ('white', 'blue', 'blue', 'blue', 'restore_red'),
#  ('white', 'blue', 'blue', 'blue', 'restore_blue'),
#  ('white', 'blue', 'blue', 'blue', 'restore_white'),
#  ('white', 'blue', 'blue', 'white', 'store_red'),
#  ('white', 'blue', 'blue', 'white', 'store_blue'),
#  ('white', 'blue', 'blue', 'white', 'store_white'),
#  ('white', 'blue', 'blue', 'white', 'restore_red'),
#  ('white', 'blue', 'blue', 'white', 'restore_blue'),
#  ('white', 'blue', 'blue', 'white', 'restore_white'),
#  ('white', 'blue', 'blue', 'empty', 'store_red'),
#  ('white', 'blue', 'blue', 'empty', 'store_blue'),
#  ('white', 'blue', 'blue', 'empty', 'store_white'),
#  ('white', 'blue', 'blue', 'empty', 'restore_red'),
#  ('white', 'blue', 'blue', 'empty', 'restore_blue'),
#  ('white', 'blue', 'blue', 'empty', 'restore_white'),
#  ('white', 'blue', 'white', 'red', 'store_red'),
#  ('white', 'blue', 'white', 'red', 'store_blue'),
#  ('white', 'blue', 'white', 'red', 'store_white'),
#  ('white', 'blue', 'white', 'red', 'restore_red'),
#  ('white', 'blue', 'white', 'red', 'restore_blue'),
#  ('white', 'blue', 'white', 'red', 'restore_white'),
#  ('white', 'blue', 'white', 'blue', 'store_red'),
#  ('white', 'blue', 'white', 'blue', 'store_blue'),
#  ('white', 'blue', 'white', 'blue', 'store_white'),
#  ('white', 'blue', 'white', 'blue', 'restore_red'),
#  ('white', 'blue', 'white', 'blue', 'restore_blue'),
#  ('white', 'blue', 'white', 'blue', 'restore_white'),
#  ('white', 'blue', 'white', 'white', 'store_red'),
#  ('white', 'blue', 'white', 'white', 'store_blue'),
#  ('white', 'blue', 'white', 'white', 'store_white'),
#  ('white', 'blue', 'white', 'white', 'restore_red'),
#  ('white', 'blue', 'white', 'white', 'restore_blue'),
#  ('white', 'blue', 'white', 'white', 'restore_white'),
#  ('white', 'blue', 'white', 'empty', 'store_red'),
#  ('white', 'blue', 'white', 'empty', 'store_blue'),
#  ('white', 'blue', 'white', 'empty', 'store_white'),
#  ('white', 'blue', 'white', 'empty', 'restore_red'),
#  ('white', 'blue', 'white', 'empty', 'restore_blue'),
#  ('white', 'blue', 'white', 'empty', 'restore_white'),
#  ('white', 'blue', 'empty', 'red', 'store_red'),
#  ('white', 'blue', 'empty', 'red', 'store_blue'),
#  ('white', 'blue', 'empty', 'red', 'store_white'),
#  ('white', 'blue', 'empty', 'red', 'restore_red'),
#  ('white', 'blue', 'empty', 'red', 'restore_blue'),
#  ('white', 'blue', 'empty', 'red', 'restore_white'),
#  ('white', 'blue', 'empty', 'blue', 'store_red'),
#  ('white', 'blue', 'empty', 'blue', 'store_blue'),
#  ('white', 'blue', 'empty', 'blue', 'store_white'),
#  ('white', 'blue', 'empty', 'blue', 'restore_red'),
#  ('white', 'blue', 'empty', 'blue', 'restore_blue'),
#  ('white', 'blue', 'empty', 'blue', 'restore_white'),
#  ('white', 'blue', 'empty', 'white', 'store_red'),
#  ('white', 'blue', 'empty', 'white', 'store_blue'),
#  ('white', 'blue', 'empty', 'white', 'store_white'),
#  ('white', 'blue', 'empty', 'white', 'restore_red'),
#  ('white', 'blue', 'empty', 'white', 'restore_blue'),
#  ('white', 'blue', 'empty', 'white', 'restore_white'),
#  ('white', 'blue', 'empty', 'empty', 'store_red'),
#  ('white', 'blue', 'empty', 'empty', 'store_blue'),
#  ('white', 'blue', 'empty', 'empty', 'store_white'),
#  ('white', 'blue', 'empty', 'empty', 'restore_red'),
#  ('white', 'blue', 'empty', 'empty', 'restore_blue'),
#  ('white', 'blue', 'empty', 'empty', 'restore_white'),
#  ('white', 'white', 'red', 'red', 'store_red'),
#  ('white', 'white', 'red', 'red', 'store_blue'),
#  ('white', 'white', 'red', 'red', 'store_white'),
#  ('white', 'white', 'red', 'red', 'restore_red'),
#  ('white', 'white', 'red', 'red', 'restore_blue'),
#  ('white', 'white', 'red', 'red', 'restore_white'),
#  ('white', 'white', 'red', 'blue', 'store_red'),
#  ('white', 'white', 'red', 'blue', 'store_blue'),
#  ('white', 'white', 'red', 'blue', 'store_white'),
#  ('white', 'white', 'red', 'blue', 'restore_red'),
#  ('white', 'white', 'red', 'blue', 'restore_blue'),
#  ('white', 'white', 'red', 'blue', 'restore_white'),
#  ('white', 'white', 'red', 'white', 'store_red'),
#  ('white', 'white', 'red', 'white', 'store_blue'),
#  ('white', 'white', 'red', 'white', 'store_white'),
#  ('white', 'white', 'red', 'white', 'restore_red'),
#  ('white', 'white', 'red', 'white', 'restore_blue'),
#  ('white', 'white', 'red', 'white', 'restore_white'),
#  ('white', 'white', 'red', 'empty', 'store_red'),
#  ('white', 'white', 'red', 'empty', 'store_blue'),
#  ('white', 'white', 'red', 'empty', 'store_white'),
#  ('white', 'white', 'red', 'empty', 'restore_red'),
#  ('white', 'white', 'red', 'empty', 'restore_blue'),
#  ('white', 'white', 'red', 'empty', 'restore_white'),
#  ('white', 'white', 'blue', 'red', 'store_red'),
#  ('white', 'white', 'blue', 'red', 'store_blue'),
#  ('white', 'white', 'blue', 'red', 'store_white'),
#  ('white', 'white', 'blue', 'red', 'restore_red'),
#  ('white', 'white', 'blue', 'red', 'restore_blue'),
#  ('white', 'white', 'blue', 'red', 'restore_white'),
#  ('white', 'white', 'blue', 'blue', 'store_red'),
#  ('white', 'white', 'blue', 'blue', 'store_blue'),
#  ('white', 'white', 'blue', 'blue', 'store_white'),
#  ('white', 'white', 'blue', 'blue', 'restore_red'),
#  ('white', 'white', 'blue', 'blue', 'restore_blue'),
#  ('white', 'white', 'blue', 'blue', 'restore_white'),
#  ('white', 'white', 'blue', 'white', 'store_red'),
#  ('white', 'white', 'blue', 'white', 'store_blue'),
#  ('white', 'white', 'blue', 'white', 'store_white'),
#  ('white', 'white', 'blue', 'white', 'restore_red'),
#  ...]

# %% [markdown]
# ### Definition of th model
# Our model consists of four cells, as we have a 2x2 warehouse matrix. Every cell is indexed by the numbers from 0 to 3.

# %%
cell_index = np.arange(0,4)
cell_index
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# The costs are defined based on the distance the roboter has to walk to the cell. We have a 2x2 field and the robot cannot walk diagonally. Thus, the minimum cost is 1 and the maximum one is 3.

# %%
distance_costs = [1,2,2,3]

# %% [markdown]
# ### Definition of the tranbsition probability matrix
# Based on the probabilities of the occurances of the actions in the dataset, we create a transition probability matrix. It indicates the probability to change from one state to another based on the distribution of the training data set.

# %%
probability_store_red = probability_evaluation.loc[(probability_evaluation['color'] == 'red') & (probability_evaluation['action'] == 'store'), 'probability'].item()
probability_store_blue = probability_evaluation.loc[(probability_evaluation['color'] == 'blue') & (probability_evaluation['action'] == 'store'), 'probability'].item()
probability_store_white = probability_evaluation.loc[(probability_evaluation['color'] == 'white') & (probability_evaluation['action'] == 'store'), 'probability'].item()
probability_restore_red = probability_evaluation.loc[(probability_evaluation['color'] == 'red') & (probability_evaluation['action'] == 'restore'), 'probability'].item()
probability_restore_blue = probability_evaluation.loc[(probability_evaluation['color'] == 'blue') & (probability_evaluation['action'] == 'restore'), 'probability'].item()
probability_restore_white = probability_evaluation.loc[(probability_evaluation['color'] == 'white') & (probability_evaluation['action'] == 'restore'), 'probability'].item()

# %%
def is_valid_transation(cell_id, current_state, next_state):
    if current_state[-1] == 'restore_red' or current_state[-1] == 'restore_blue' or current_state[-1] == 'restore_white':
        if next_state[-1][cell_id] == 'empty' and current_state[-1][cell_id] == current_state[-1].split('_')[1]:
            return True
            #if np.count_nonzero(current_state[-1] == next_state)==3:
            #    return True
    elif current_state[-1] == 'store_red' or current_state[-1] == 'store_blue' or current_state[-1] == 'store_white':
        if next_state[-1][cell_id] == current_state[-1].split('_')[1] and current_state[-1][cell_id] == 'empty': 
            #if np.count_nonzero(current_state[-1] == next_state)==3:
            return True
    return False

# %% [markdown]
# If there is a row consisting only of zeros, we will set a 100% = 1 transition probability to stay in the current state. Moreover, we normalize the probabilities of entering in another state, so that these sum up to 1.

# %%
def normalize(matrix):
    for index, row in enumerate(matrix):
        if np.sum(row) == 0:
            matrix[index, index] = 1
            continue

    corrected_matrix =matrix / matrix.sum(axis=1)[:, np.newaxis]
    return corrected_matrix

# %%
tpm_matrix = []

for cell_id in cell_index:
    tpm_per_cell = np.zeros((len(state_matrix), len(state_matrix)), dtype=np.float16)
    for i, current_state in enumerate(state_matrix):
        for j, next_state in enumerate(state_matrix):
            if is_valid_transation(cell_id, current_state, next_state):
                next_action = next_state[4]
                if next_action == 'store_red':
                    tpm_per_cell[i, j] = probability_store_red
                elif next_action == 'store_blue':
                    tpm_per_cell[i, j] = probability_store_blue
                elif next_action == 'store_white':
                    tpm_per_cell[i, j] = probability_store_white
                elif next_action == 'restore_red':
                    tpm_per_cell[i, j] = probability_restore_red
                elif next_action == 'restore_white':
                    tpm_per_cell[i, j] = probability_restore_white
                else:
                    tpm_per_cell[i, j] = probability_restore_blue        
    tpm_matrix.append(normalize(tpm_per_cell))

# %% [markdown]
# ### Definition of the reward matrix

# %%
rewards = [3,2,2,1]
def create_reward_matrix():

    reward_matrix = np.zeros((len(state_matrix), len(cell_index)))
    for cell_id in cell_index:
        for i, state in enumerate(state_matrix):
            if state[-1].split('_')[0] == 'restore':
                #restoring if color is suiting
                if state[cell_id] == state[-1].split('_')[1]:
                    reward_matrix[i, cell_id] = rewards[cell_id] 
                else:
                    reward_matrix[i, cell_id] = -10
            elif state[-1].split('_')[0] == 'store':
                # Storing possible if empty cell there
                if state[cell_id] =='empty':
                    reward_matrix[i, cell_id] = rewards[cell_id]
                else:
                    reward_matrix[i, cell_id] = -10
    return reward_matrix

# %%
reward_matrix = create_reward_matrix()

# %% [markdown]
# ### Greedy approach
# If neither storing nor restoring is possible, costs of distance_costs[0] = 1 are added to the total costs.

# %%
def greedy_helper(current_warehouse):
    current_warehouse = copy.deepcopy(current_warehouse)
    result = current_warehouse[:4]
    task = current_warehouse[4]
    color = current_warehouse[-1]
    if task =='store':
        for i, field in enumerate(result):
            if field=='empty':
                current_warehouse[i]=color
                return current_warehouse, i

    elif task == 'restore':
        for i, field in enumerate(result):
            if field == color:
                current_warehouse[i]='empty'
                return current_warehouse, i
    return current_warehouse, 0

# %%
def greedy_distance(data_set):
    greedy_warehouse = ['empty', 'empty', 'empty','empty','-','-']
    total_reward = 0
    greedy_warehouse_states=list()
    
    for i, data_row in data_set.iterrows():
        greedy_warehouse[4] = data_row.action
        greedy_warehouse[5] = data_row.color
        
        greedy_warehouse, action = greedy_helper(greedy_warehouse)
        greedy_warehouse_states.append(tuple(greedy_warehouse))
        total_reward = total_reward + (distance_costs[action]*2)
        
    return [total_reward, greedy_warehouse_states]

# %% [markdown]
# ### Test code

# %%
def get_new_warehouse(warehouse, pos, action, color):
    new_warehouse = copy.deepcopy(warehouse)
    if action == 'restore' and warehouse[pos] == color:
        new_warehouse[pos] = 'empty'
    elif action == 'store' and warehouse[pos] == 'empty':
        new_warehouse[pos] = color
    return new_warehouse

# %%
def get_state_index(warehouse):
    for i, row in enumerate(state_matrix):
        if list(row) == warehouse:
            return i
        
    return 'failure'

# %%
def evaluate_performance(policy, data):
    
    warehouse = ['empty', 'empty','empty', 'empty','empty']
    next_cell_position = 0
    new_warehouse_state_list = list()
    
    for i, row in data.iterrows():
        warehouse[len(cell_index)] = row.action+"_"+row.color
        state_index = get_state_index(warehouse)
        if state_index == 'failure':
            print('Failure:')
            return 'failure'
        else:
            next_cell_position += distance_costs[policy[state_index]] * 2
            warehouse = get_new_warehouse(warehouse, policy[state_index], row.action, row.color)
            new_warehouse_state_list.append(tuple(warehouse))
    return [next_cell_position, new_warehouse_state_list]

# %% [markdown]
# ### Markov Decision Process Toolbox for policy generation

# %%
mdpPolicy = mdptoolbox.mdp.PolicyIteration(tpm_matrix, reward_matrix, 0.3, max_iter=100)
mdpValue = mdptoolbox.mdp.ValueIteration(tpm_matrix, reward_matrix, 0.3, max_iter=100)
mdpPolicy.run()
mdpValue.run()

# %% [markdown]
# #### Evaluation on Training data set

# %%
mdp_result_policy_results_training = evaluate_performance(mdpPolicy.policy, warehouse_training)
mdp_result_value_results_training = evaluate_performance(mdpValue.policy, warehouse_training)

# %%
greedy_distance(warehouse_order)
# Out:
# [228,
#  [('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('red', 'red', 'blue', 'red', 'store', 'red'),
#   ('empty', 'red', 'blue', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'blue', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'blue', 'empty', 'store', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('red', 'red', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('red', 'red', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'white', 'empty', 'store', 'white'),
#   ('blue', 'red', 'white', 'red', 'store', 'red'),
#   ('blue', 'empty', 'white', 'red', 'restore', 'red'),
#   ('blue', 'empty', 'white', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'white', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'white', 'empty', 'store', 'red'),
#   ('empty', 'empty', 'white', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'white', 'empty', 'store', 'white'),
#   ('white', 'red', 'white', 'empty', 'store', 'red'),
#   ('white', 'red', 'white', 'red', 'store', 'red'),
#   ('white', 'empty', 'white', 'red', 'restore', 'red'),
#   ('white', 'red', 'white', 'red', 'store', 'red'),
#   ('white', 'empty', 'white', 'red', 'restore', 'red'),
#   ('white', 'empty', 'white', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'white', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'empty', 'empty', 'store', 'white'),
#   ('blue', 'white', 'blue', 'empty', 'store', 'blue'),
#   ('blue', 'empty', 'blue', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'empty', 'empty', 'store', 'red'),
#   ('white', 'red', 'red', 'empty', 'store', 'red'),
#   ('white', 'red', 'red', 'red', 'store', 'red'),
#   ('white', 'empty', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'blue', 'empty', 'store', 'blue'),
#   ('white', 'white', 'blue', 'white', 'store', 'white'),
#   ('white', 'white', 'empty', 'white', 'restore', 'blue'),
#   ('empty', 'white', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'white'),
#   ('white', 'empty', 'empty', 'white', 'store', 'white'),
#   ('white', 'red', 'empty', 'white', 'store', 'red')]]

# %% [markdown]
# #### Evaluation on Training data set

# %%
greedy_distance(warehouse_training)
# Out:
# [28802,
#  [('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'white', 'store', 'white'),
#   ('empty', 'red', 'red', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('empty', 'blue', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'blue', 'empty', 'empty', 'store', 'red'),
#   ('red', 'blue', 'white', 'empty', 'store', 'white'),
#   ('red', 'blue', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'blue', 'red', 'empty', 'store', 'red'),
#   ('empty', 'blue', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'blue', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'blue', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'blue', 'white', 'store', 'white'),
#   ('empty', 'blue', 'blue', 'white', 'restore', 'blue'),
#   ('empty', 'empty', 'blue', 'white', 'restore', 'blue'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'blue', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'blue', 'empty', 'store', 'blue'),
#   ('empty', 'blue', 'blue', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'blue', 'empty', 'store', 'red'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'blue', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'blue', 'empty', 'store', 'blue'),
#   ('empty', 'blue', 'blue', 'empty', 'restore', 'blue'),
#   ('red', 'blue', 'blue', 'empty', 'store', 'red'),
#   ('red', 'empty', 'blue', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'white', 'empty', 'store', 'white'),
#   ('red', 'red', 'white', 'red', 'store', 'red'),
#   ('red', 'red', 'empty', 'red', 'restore', 'white'),
#   ('empty', 'red', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'blue', 'empty', 'store', 'blue'),
#   ('red', 'white', 'blue', 'white', 'store', 'white'),
#   ('red', 'empty', 'blue', 'white', 'restore', 'white'),
#   ('red', 'red', 'blue', 'white', 'store', 'red'),
#   ('red', 'red', 'blue', 'empty', 'restore', 'white'),
#   ('empty', 'red', 'blue', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'blue', 'empty', 'store', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('blue', 'red', 'red', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'red', 'red', 'store', 'red'),
#   ('empty', 'red', 'red', 'red', 'restore', 'blue'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('red', 'blue', 'red', 'empty', 'store', 'red'),
#   ('red', 'blue', 'red', 'red', 'store', 'red'),
#   ('empty', 'blue', 'red', 'red', 'restore', 'red'),
#   ('empty', 'blue', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'blue'),
#   ('white', 'empty', 'empty', 'red', 'store', 'white'),
#   ('white', 'red', 'empty', 'red', 'store', 'red'),
#   ('white', 'red', 'blue', 'red', 'store', 'blue'),
#   ('white', 'empty', 'blue', 'red', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'red', 'restore', 'blue'),
#   ('white', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'red', 'empty', 'store', 'red'),
#   ('red', 'white', 'red', 'red', 'store', 'red'),
#   ('empty', 'white', 'red', 'red', 'restore', 'red'),
#   ('blue', 'white', 'red', 'red', 'store', 'blue'),
#   ('blue', 'white', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'white', 'empty', 'red', 'restore', 'blue'),
#   ('empty', 'white', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'white', 'empty', 'store', 'white'),
#   ('blue', 'red', 'white', 'red', 'store', 'red'),
#   ('blue', 'empty', 'white', 'red', 'restore', 'red'),
#   ('blue', 'empty', 'white', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'white', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'empty', 'empty', 'store', 'red'),
#   ('white', 'red', 'red', 'empty', 'store', 'red'),
#   ('white', 'red', 'red', 'red', 'store', 'red'),
#   ('white', 'empty', 'red', 'red', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('white', 'red', 'empty', 'red', 'store', 'red'),
#   ('white', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'blue', 'store', 'blue'),
#   ('red', 'red', 'red', 'empty', 'restore', 'blue'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'blue', 'empty', 'store', 'blue'),
#   ('red', 'white', 'blue', 'blue', 'store', 'blue'),
#   ('red', 'white', 'empty', 'blue', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'blue', 'restore', 'white'),
#   ('red', 'white', 'empty', 'blue', 'store', 'white'),
#   ('empty', 'white', 'empty', 'blue', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'blue', 'restore', 'white'),
#   ('white', 'empty', 'empty', 'blue', 'store', 'white'),
#   ('white', 'white', 'empty', 'blue', 'store', 'white'),
#   ('empty', 'white', 'empty', 'blue', 'restore', 'white'),
#   ('empty', 'white', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'blue', 'store', 'blue'),
#   ('red', 'red', 'red', 'empty', 'restore', 'blue'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'blue', 'store', 'blue'),
#   ('empty', 'red', 'red', 'blue', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'blue', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'red', 'store', 'red'),
#   ('empty', 'red', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'red'),
#   ('red', 'empty', 'red', 'red', 'store', 'red'),
#   ('red', 'red', 'red', 'red', 'store', 'red'),
#   ('empty', 'red', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'red'),
#   ('red', 'empty', 'red', 'red', 'store', 'red'),
#   ('red', 'white', 'red', 'red', 'store', 'white'),
#   ('red', 'empty', 'red', 'red', 'restore', 'white'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'red'),
#   ('blue', 'empty', 'red', 'red', 'store', 'blue'),
#   ('blue', 'red', 'red', 'red', 'store', 'red'),
#   ('blue', 'empty', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'blue'),
#   ('red', 'empty', 'red', 'red', 'store', 'red'),
#   ('red', 'blue', 'red', 'red', 'store', 'blue'),
#   ('empty', 'blue', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'red', 'empty', 'store', 'red'),
#   ('white', 'white', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'white', 'empty', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'blue', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'blue', 'red', 'store', 'red'),
#   ('blue', 'blue', 'blue', 'empty', 'restore', 'red'),
#   ('empty', 'blue', 'blue', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'empty', 'empty', 'store', 'white'),
#   ('blue', 'white', 'blue', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'blue', 'red', 'store', 'red'),
#   ('blue', 'white', 'blue', 'empty', 'restore', 'red'),
#   ('blue', 'white', 'blue', 'white', 'store', 'white'),
#   ('blue', 'empty', 'blue', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'blue', 'white', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'blue'),
#   ('blue', 'empty', 'empty', 'white', 'store', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'red', 'empty', 'store', 'red'),
#   ('blue', 'blue', 'red', 'red', 'store', 'red'),
#   ('blue', 'blue', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'blue', 'empty', 'red', 'restore', 'blue'),
#   ('empty', 'blue', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'empty', 'empty', 'store', 'red'),
#   ('white', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('white', 'red', 'empty', 'empty', 'restore', 'blue'),
#   ('white', 'red', 'red', 'empty', 'store', 'red'),
#   ('white', 'red', 'red', 'white', 'store', 'white'),
#   ('white', 'empty', 'red', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('red', 'red', 'blue', 'red', 'store', 'red'),
#   ('red', 'red', 'empty', 'red', 'restore', 'blue'),
#   ('empty', 'red', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'white'),
#   ('white', 'red', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'red', 'empty', 'store', 'red'),
#   ('white', 'red', 'red', 'blue', 'store', 'blue'),
#   ('empty', 'red', 'red', 'blue', 'restore', 'white'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'empty', 'empty', 'store', 'white'),
#   ('blue', 'white', 'white', 'empty', 'store', 'white'),
#   ('blue', 'white', 'white', 'blue', 'store', 'blue'),
#   ('blue', 'empty', 'white', 'blue', 'restore', 'white'),
#   ('empty', 'empty', 'white', 'blue', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'blue', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'white', 'empty', 'store', 'white'),
#   ('empty', 'blue', 'white', 'empty', 'restore', 'blue'),
#   ('empty', 'blue', 'empty', 'empty', 'restore', 'white'),
#   ('blue', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'red', 'empty', 'store', 'red'),
#   ('blue', 'blue', 'red', 'blue', 'store', 'blue'),
#   ('blue', 'blue', 'empty', 'blue', 'restore', 'red'),
#   ('empty', 'blue', 'empty', 'blue', 'restore', 'blue'),
#   ('red', 'blue', 'empty', 'blue', 'store', 'red'),
#   ('red', 'blue', 'red', 'blue', 'store', 'red'),
#   ('empty', 'blue', 'red', 'blue', 'restore', 'red'),
#   ('empty', 'blue', 'empty', 'blue', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'blue', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('empty', 'red', 'blue', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'blue', 'empty', 'store', 'blue'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'blue'),
#   ('white', 'empty', 'blue', 'empty', 'store', 'white'),
#   ('white', 'red', 'blue', 'empty', 'store', 'red'),
#   ('white', 'red', 'blue', 'white', 'store', 'white'),
#   ('empty', 'red', 'blue', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'blue', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'blue', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'blue', 'empty', 'store', 'blue'),
#   ('empty', 'blue', 'blue', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('empty', 'red', 'blue', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'red', 'empty', 'store', 'red'),
#   ('blue', 'blue', 'red', 'red', 'store', 'red'),
#   ('blue', 'blue', 'empty', 'red', 'restore', 'red'),
#   ('blue', 'blue', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'blue', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('empty', 'blue', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'blue', 'empty', 'empty', 'store', 'red'),
#   ('red', 'blue', 'white', 'empty', 'store', 'white'),
#   ('red', 'blue', 'white', 'blue', 'store', 'blue'),
#   ('red', 'empty', 'white', 'blue', 'restore', 'blue'),
#   ('red', 'blue', 'white', 'blue', 'store', 'blue'),
#   ('empty', 'blue', 'white', 'blue', 'restore', 'red'),
#   ('empty', 'empty', 'white', 'blue', 'restore', 'blue'),
#   ('white', 'empty', 'white', 'blue', 'store', 'white'),
#   ('white', 'white', 'white', 'blue', 'store', 'white'),
#   ('empty', 'white', 'white', 'blue', 'restore', 'white'),
#   ('empty', 'white', 'white', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'white', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'white', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'white', 'empty', 'store', 'red'),
#   ('blue', 'red', 'white', 'blue', 'store', 'blue'),
#   ('blue', 'empty', 'white', 'blue', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'blue', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'blue', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'empty', 'empty', 'store', 'red'),
#   ('white', 'red', 'red', 'empty', 'store', 'red'),
#   ('white', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'white', 'empty', 'store', 'white'),
#   ('white', 'white', 'white', 'red', 'store', 'red'),
#   ('white', 'white', 'white', 'empty', 'restore', 'red'),
#   ('empty', 'white', 'white', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'white', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'white', 'empty', 'store', 'red'),
#   ('red', 'red', 'white', 'empty', 'store', 'red'),
#   ('red', 'red', 'white', 'white', 'store', 'white'),
#   ('empty', 'red', 'white', 'white', 'restore', 'red'),
#   ('empty', 'red', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'white'),
#   ('white', 'red', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('white', 'red', 'blue', 'white', 'store', 'white'),
#   ('empty', 'red', 'blue', 'white', 'restore', 'white'),
#   ('empty', 'red', 'empty', 'white', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'blue', 'empty', 'store', 'blue'),
#   ('white', 'white', 'blue', 'red', 'store', 'red'),
#   ('white', 'white', 'blue', 'empty', 'restore', 'red'),
#   ('empty', 'white', 'blue', 'empty', 'restore', 'white'),
#   ('red', 'white', 'blue', 'empty', 'store', 'red'),
#   ('red', 'white', 'blue', 'red', 'store', 'red'),
#   ('empty', 'white', 'blue', 'red', 'restore', 'red'),
#   ('empty', 'white', 'empty', 'red', 'restore', 'blue'),
#   ('red', 'white', 'empty', 'red', 'store', 'red'),
#   ('empty', 'white', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'white', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'white', 'empty', 'store', 'white'),
#   ('red', 'white', 'white', 'red', 'store', 'red'),
#   ('empty', 'white', 'white', 'red', 'restore', 'red'),
#   ('empty', 'white', 'white', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'white', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'empty', 'empty', 'store', 'white'),
#   ('blue', 'white', 'white', 'empty', 'store', 'white'),
#   ('blue', 'white', 'white', 'red', 'store', 'red'),
#   ('blue', 'white', 'white', 'empty', 'restore', 'red'),
#   ('blue', 'white', 'white', 'red', 'store', 'red'),
#   ('blue', 'white', 'white', 'empty', 'restore', 'red'),
#   ('blue', 'white', 'white', 'red', 'store', 'red'),
#   ('blue', 'empty', 'white', 'red', 'restore', 'white'),
#   ('blue', 'red', 'white', 'red', 'store', 'red'),
#   ('blue', 'red', 'empty', 'red', 'restore', 'white'),
#   ('empty', 'red', 'empty', 'red', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'red', 'store', 'red'),
#   ('red', 'red', 'empty', 'red', 'store', 'red'),
#   ('empty', 'red', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'red', 'store', 'red'),
#   ('red', 'blue', 'empty', 'red', 'store', 'blue'),
#   ('red', 'blue', 'blue', 'red', 'store', 'blue'),
#   ('red', 'empty', 'blue', 'red', 'restore', 'blue'),
#   ('empty', 'empty', 'blue', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'empty', 'empty', 'store', 'red'),
#   ('white', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('white', 'red', 'blue', 'red', 'store', 'red'),
#   ('white', 'red', 'empty', 'red', 'restore', 'blue'),
#   ('white', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'red'),
#   ('blue', 'red', 'red', 'empty', 'store', 'red'),
#   ('blue', 'red', 'red', 'white', 'store', 'white'),
#   ('blue', 'empty', 'red', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'white', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'red'),
#   ('blue', 'red', 'white', 'empty', 'store', 'white'),
#   ('blue', 'red', 'white', 'white', 'store', 'white'),
#   ('blue', 'empty', 'white', 'white', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'white', 'restore', 'white'),
#   ('blue', 'red', 'empty', 'white', 'store', 'red'),
#   ('blue', 'red', 'white', 'white', 'store', 'white'),
#   ('blue', 'empty', 'white', 'white', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'white', 'empty', 'store', 'white'),
#   ('red', 'white', 'white', 'red', 'store', 'red'),
#   ('empty', 'white', 'white', 'red', 'restore', 'red'),
#   ('blue', 'white', 'white', 'red', 'store', 'blue'),
#   ('empty', 'white', 'white', 'red', 'restore', 'blue'),
#   ('empty', 'white', 'white', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'white', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'white', 'empty', 'store', 'red'),
#   ('red', 'white', 'white', 'empty', 'store', 'white'),
#   ('red', 'white', 'white', 'white', 'store', 'white'),
#   ('empty', 'white', 'white', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'white', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('red', 'blue', 'blue', 'empty', 'store', 'blue'),
#   ('red', 'blue', 'blue', 'blue', 'store', 'blue'),
#   ('red', 'empty', 'blue', 'blue', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'blue', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'blue', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'blue', 'store', 'white'),
#   ('white', 'red', 'empty', 'blue', 'store', 'red'),
#   ('white', 'red', 'red', 'blue', 'store', 'red'),
#   ('white', 'red', 'red', 'empty', 'restore', 'blue'),
#   ('white', 'red', 'red', 'red', 'store', 'red'),
#   ('white', 'empty', 'red', 'red', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'white', 'empty', 'store', 'white'),
#   ('empty', 'white', 'white', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'white', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'red', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'red', 'empty', 'store', 'white'),
#   ('blue', 'empty', 'red', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'empty', 'empty', 'store', 'red'),
#   ('white', 'red', 'red', 'empty', 'store', 'red'),
#   ('white', 'red', 'red', 'red', 'store', 'red'),
#   ('empty', 'red', 'red', 'red', 'restore', 'white'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'red', 'empty', 'store', 'red'),
#   ('white', 'white', 'red', 'white', 'store', 'white'),
#   ('empty', 'white', 'red', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'red', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'red', 'store', 'red'),
#   ('empty', 'red', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'empty', 'empty', 'store', 'white'),
#   ('blue', 'white', 'white', 'empty', 'store', 'white'),
#   ('blue', 'empty', 'white', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'white', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'white', 'store', 'white'),
#   ('red', 'red', 'red', 'empty', 'restore', 'white'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('blue', 'red', 'red', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'red', 'blue', 'store', 'blue'),
#   ('blue', 'empty', 'red', 'blue', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'blue', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'blue', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'red', 'empty', 'store', 'red'),
#   ('red', 'white', 'red', 'white', 'store', 'white'),
#   ('empty', 'white', 'red', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'white', 'restore', 'white'),
#   ('red', 'empty', 'red', 'white', 'store', 'red'),
#   ('empty', 'empty', 'red', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'blue', 'store', 'blue'),
#   ('red', 'red', 'red', 'empty', 'restore', 'blue'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'red'),
#   ('blue', 'red', 'red', 'empty', 'store', 'red'),
#   ('blue', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('empty', 'blue', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'blue', 'empty', 'empty', 'store', 'white'),
#   ('white', 'blue', 'red', 'empty', 'store', 'red'),
#   ('white', 'blue', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('white', 'white', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'red', 'empty', 'store', 'red'),
#   ('white', 'white', 'red', 'red', 'store', 'red'),
#   ('white', 'white', 'empty', 'red', 'restore', 'red'),
#   ('white', 'white', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'white', 'empty', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('white', 'blue', 'red', 'empty', 'store', 'red'),
#   ('white', 'blue', 'red', 'red', 'store', 'red'),
#   ('white', 'blue', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'blue', 'empty', 'red', 'restore', 'white'),
#   ('empty', 'blue', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'red'),
#   ('blue', 'red', 'red', 'empty', 'store', 'red'),
#   ('blue', 'red', 'red', 'red', 'store', 'red'),
#   ('empty', 'red', 'red', 'red', 'restore', 'blue'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'red', 'store', 'red'),
#   ('red', 'red', 'empty', 'red', 'store', 'red'),
#   ('empty', 'red', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'red', 'store', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('red', 'red', 'blue', 'red', 'store', 'red'),
#   ('empty', 'red', 'blue', 'red', 'restore', 'red'),
#   ('empty', 'red', 'empty', 'red', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'red', 'store', 'white'),
#   ('white', 'red', 'empty', 'red', 'store', 'red'),
#   ('white', 'red', 'red', 'red', 'store', 'red'),
#   ('white', 'empty', 'red', 'red', 'restore', 'red'),
#   ('white', 'red', 'red', 'red', 'store', 'red'),
#   ('white', 'empty', 'red', 'red', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'red', 'empty', 'store', 'red'),
#   ('red', 'white', 'red', 'blue', 'store', 'blue'),
#   ('red', 'white', 'red', 'empty', 'restore', 'blue'),
#   ('empty', 'white', 'red', 'empty', 'restore', 'red'),
#   ('blue', 'white', 'red', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'red', 'white', 'store', 'white'),
#   ('blue', 'white', 'empty', 'white', 'restore', 'red'),
#   ('empty', 'white', 'empty', 'white', 'restore', 'blue'),
#   ('red', 'white', 'empty', 'white', 'store', 'red'),
#   ('red', 'white', 'blue', 'white', 'store', 'blue'),
#   ('red', 'white', 'empty', 'white', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'white', 'restore', 'white'),
#   ('red', 'blue', 'empty', 'white', 'store', 'blue'),
#   ('red', 'blue', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'blue', 'blue', 'empty', 'store', 'blue'),
#   ('red', 'blue', 'blue', 'red', 'store', 'red'),
#   ('red', 'empty', 'blue', 'red', 'restore', 'blue'),
#   ('empty', 'empty', 'blue', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'red', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'white', 'empty', 'store', 'white'),
#   ('white', 'red', 'white', 'white', 'store', 'white'),
#   ('empty', 'red', 'white', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'white', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('red', 'blue', 'white', 'empty', 'store', 'white'),
#   ('red', 'blue', 'white', 'white', 'store', 'white'),
#   ('red', 'blue', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'blue', 'empty', 'white', 'restore', 'red'),
#   ('red', 'blue', 'empty', 'white', 'store', 'red'),
#   ('red', 'blue', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'empty', 'empty', 'store', 'white'),
#   ('blue', 'white', 'white', 'empty', 'store', 'white'),
#   ('blue', 'white', 'white', 'red', 'store', 'red'),
#   ('blue', 'white', 'white', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'white', 'empty', 'restore', 'white'),
#   ('blue', 'red', 'white', 'empty', 'store', 'red'),
#   ('empty', 'red', 'white', 'empty', 'restore', 'blue'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('empty', 'red', 'blue', 'empty', 'restore', 'red'),
#   ('blue', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('blue', 'empty', 'blue', 'empty', 'restore', 'red'),
#   ('blue', 'blue', 'blue', 'empty', 'store', 'blue'),
#   ('empty', 'blue', 'blue', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'blue', 'empty', 'store', 'red'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'blue', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'blue', 'empty', 'store', 'red'),
#   ('blue', 'red', 'blue', 'white', 'store', 'white'),
#   ('blue', 'empty', 'blue', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'blue', 'white', 'restore', 'blue'),
#   ('red', 'empty', 'blue', 'white', 'store', 'red'),
#   ('red', 'blue', 'blue', 'white', 'store', 'blue'),
#   ('red', 'empty', 'blue', 'white', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'white', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('empty', 'red', 'blue', 'empty', 'restore', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'red', 'empty', 'store', 'red'),
#   ('white', 'white', 'red', 'white', 'store', 'white'),
#   ('white', 'white', 'empty', 'white', 'restore', 'red'),
#   ('empty', 'white', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'red', 'empty', 'store', 'red'),
#   ('red', 'empty', 'red', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'red', 'store', 'red'),
#   ('empty', 'red', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'red', 'store', 'red'),
#   ('red', 'red', 'empty', 'red', 'store', 'red'),
#   ('red', 'red', 'white', 'red', 'store', 'white'),
#   ('red', 'red', 'empty', 'red', 'restore', 'white'),
#   ('red', 'red', 'blue', 'red', 'store', 'blue'),
#   ('red', 'red', 'empty', 'red', 'restore', 'blue'),
#   ('empty', 'red', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'red', 'store', 'red'),
#   ('red', 'blue', 'empty', 'red', 'store', 'blue'),
#   ('red', 'blue', 'white', 'red', 'store', 'white'),
#   ('empty', 'blue', 'white', 'red', 'restore', 'red'),
#   ('empty', 'blue', 'white', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'white', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'white', 'empty', 'store', 'red'),
#   ('red', 'red', 'white', 'empty', 'store', 'red'),
#   ('red', 'red', 'white', 'white', 'store', 'white'),
#   ('empty', 'red', 'white', 'white', 'restore', 'red'),
#   ('empty', 'red', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'white', 'store', 'white'),
#   ('white', 'white', 'empty', 'white', 'store', 'white'),
#   ('white', 'white', 'red', 'white', 'store', 'red'),
#   ('white', 'white', 'empty', 'white', 'restore', 'red'),
#   ('empty', 'white', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'empty', 'empty', 'store', 'white'),
#   ('blue', 'white', 'blue', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'blue', 'white', 'store', 'white'),
#   ('empty', 'white', 'blue', 'white', 'restore', 'blue'),
#   ('empty', 'white', 'empty', 'white', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'red', 'empty', 'empty', 'store', 'white'),
#   ('white', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'red', 'empty', 'empty', 'store', 'red'),
#   ('white', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('white', 'empty', 'blue', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'empty', 'empty', 'store', 'white'),
#   ('white', 'white', 'red', 'empty', 'store', 'red'),
#   ('empty', 'white', 'red', 'empty', 'restore', 'white'),
#   ('red', 'white', 'red', 'empty', 'store', 'red'),
#   ('empty', 'white', 'red', 'empty', 'restore', 'red'),
#   ('white', 'white', 'red', 'empty', 'store', 'white'),
#   ('white', 'white', 'red', 'red', 'store', 'red'),
#   ('white', 'white', 'empty', 'red', 'restore', 'red'),
#   ('white', 'white', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'white', 'empty', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'red', 'empty', 'empty', 'store', 'white'),
#   ('white', 'red', 'red', 'empty', 'store', 'red'),
#   ('white', 'red', 'red', 'blue', 'store', 'blue'),
#   ('empty', 'red', 'red', 'blue', 'restore', 'white'),
#   ('empty', 'empty', 'red', 'blue', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'blue', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'blue', 'store', 'blue'),
#   ('blue', 'white', 'empty', 'blue', 'store', 'white'),
#   ('blue', 'white', 'red', 'blue', 'store', 'red'),
#   ('blue', 'white', 'empty', 'blue', 'restore', 'red'),
#   ('empty', 'white', 'empty', 'blue', 'restore', 'blue'),
#   ('empty', 'white', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'white', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'red', 'empty', 'store', 'red'),
#   ('blue', 'white', 'red', 'blue', 'store', 'blue'),
#   ('blue', 'empty', 'red', 'blue', 'restore', 'white'),
#   ('blue', 'empty', 'empty', 'blue', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'blue', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'blue', 'empty', 'store', 'blue'),
#   ('red', 'white', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'white', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'white', 'empty', 'empty', 'store', 'white'),
#   ('blue', 'white', 'red', 'empty', 'store', 'red'),
#   ('blue', 'white', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'white', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'red', 'empty', 'store', 'red'),
#   ('blue', 'blue', 'red', 'red', 'store', 'red'),
#   ('empty', 'blue', 'red', 'red', 'restore', 'blue'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'blue'),
#   ('red', 'empty', 'red', 'red', 'store', 'red'),
#   ('red', 'red', 'red', 'red', 'store', 'red'),
#   ('empty', 'red', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'red'),
#   ('blue', 'empty', 'red', 'red', 'store', 'blue'),
#   ('blue', 'red', 'red', 'red', 'store', 'red'),
#   ('blue', 'empty', 'red', 'red', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('empty', 'blue', 'empty', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'empty', 'store', 'red'),
#   ('red', 'red', 'red', 'red', 'store', 'red'),
#   ('empty', 'red', 'red', 'red', 'restore', 'red'),
#   ('red', 'red', 'red', 'red', 'store', 'red'),
#   ('empty', 'red', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'red', 'empty', 'store', 'red'),
#   ('red', 'white', 'red', 'white', 'store', 'white'),
#   ('red', 'empty', 'red', 'white', 'restore', 'white'),
#   ('red', 'empty', 'red', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'red', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'red', 'empty', 'store', 'red'),
#   ('blue', 'red', 'red', 'blue', 'store', 'blue'),
#   ('blue', 'empty', 'red', 'blue', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'blue', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'blue', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'blue', 'store', 'white'),
#   ('white', 'red', 'empty', 'blue', 'store', 'red'),
#   ('empty', 'red', 'empty', 'blue', 'restore', 'white'),
#   ('blue', 'red', 'empty', 'blue', 'store', 'blue'),
#   ('blue', 'empty', 'empty', 'blue', 'restore', 'red'),
#   ('blue', 'red', 'empty', 'blue', 'store', 'red'),
#   ('blue', 'red', 'red', 'blue', 'store', 'red'),
#   ('empty', 'red', 'red', 'blue', 'restore', 'blue'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'blue'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'red', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'red', 'empty', 'store', 'red'),
#   ('blue', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'red'),
#   ('blue', 'red', 'red', 'empty', 'store', 'red'),
#   ('blue', 'red', 'red', 'red', 'store', 'red'),
#   ('empty', 'red', 'red', 'red', 'restore', 'blue'),
#   ('empty', 'empty', 'red', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'red', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'blue', 'empty', 'empty', 'store', 'blue'),
#   ('red', 'blue', 'red', 'empty', 'store', 'red'),
#   ('red', 'blue', 'red', 'white', 'store', 'white'),
#   ('empty', 'blue', 'red', 'white', 'restore', 'red'),
#   ('empty', 'blue', 'red', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'blue'),
#   ('red', 'empty', 'red', 'empty', 'store', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'red'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'red'),
#   ('blue', 'red', 'red', 'empty', 'store', 'red'),
#   ('blue', 'red', 'red', 'white', 'store', 'white'),
#   ('empty', 'red', 'red', 'white', 'restore', 'blue'),
#   ('empty', 'empty', 'red', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('white', 'empty', 'empty', 'empty', 'store', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'red'),
#   ('blue', 'red', 'blue', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'blue', 'white', 'store', 'white'),
#   ('blue', 'empty', 'blue', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'blue', 'white', 'restore', 'blue'),
#   ('empty', 'empty', 'blue', 'empty', 'restore', 'white'),
#   ('white', 'empty', 'blue', 'empty', 'store', 'white'),
#   ('white', 'blue', 'blue', 'empty', 'store', 'blue'),
#   ('white', 'blue', 'blue', 'white', 'store', 'white'),
#   ('white', 'empty', 'blue', 'white', 'restore', 'blue'),
#   ('empty', 'empty', 'blue', 'white', 'restore', 'white'),
#   ('white', 'empty', 'blue', 'white', 'store', 'white'),
#   ('white', 'empty', 'empty', 'white', 'restore', 'blue'),
#   ('white', 'red', 'empty', 'white', 'store', 'red'),
#   ('empty', 'red', 'empty', 'white', 'restore', 'white'),
#   ('empty', 'red', 'empty', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('red', 'empty', 'empty', 'empty', 'store', 'red'),
#   ('red', 'white', 'empty', 'empty', 'store', 'white'),
#   ('red', 'white', 'red', 'empty', 'store', 'red'),
#   ('empty', 'white', 'red', 'empty', 'restore', 'red'),
#   ('red', 'white', 'red', 'empty', 'store', 'red'),
#   ('empty', 'white', 'red', 'empty', 'restore', 'red'),
#   ('blue', 'white', 'red', 'empty', 'store', 'blue'),
#   ('empty', 'white', 'red', 'empty', 'restore', 'blue'),
#   ('blue', 'white', 'red', 'empty', 'store', 'blue'),
#   ('blue', 'empty', 'red', 'empty', 'restore', 'white'),
#   ('blue', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'red'),
#   ('blue', 'red', 'white', 'empty', 'store', 'white'),
#   ('blue', 'red', 'white', 'white', 'store', 'white'),
#   ('blue', 'empty', 'white', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'white', 'white', 'restore', 'blue'),
#   ('empty', 'empty', 'empty', 'white', 'restore', 'white'),
#   ('red', 'empty', 'empty', 'white', 'store', 'red'),
#   ('red', 'red', 'empty', 'white', 'store', 'red'),
#   ('red', 'red', 'red', 'white', 'store', 'red'),
#   ('empty', 'red', 'red', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'white', 'restore', 'red'),
#   ('empty', 'empty', 'red', 'empty', 'restore', 'white'),
#   ('empty', 'empty', 'empty', 'empty', 'restore', 'red'),
#   ('blue', 'empty', 'empty', 'empty', 'store', 'blue'),
#   ('blue', 'red', 'empty', 'empty', 'store', 'red'),
#   ('blue', 'red', 'red', 'empty', 'store', 'red'),
#   ('empty', 'red', 'red', 'empty', 'restore', 'blue'),
#   ...]]

# %% [markdown]
# #### Evaluation on Training data set

# %%
print("ValueIteration Robot's travel distance: ", mdp_result_policy_results_training[0])
print("PolicyIteration Robot's travel distance: ", mdp_result_value_results_training[0])
print("Greedy Robot's travel distance: ", greedy_distance(warehouse_training)[0])
# Out:
# ValueIteration Robot's travel distance:  28802
# PolicyIteration Robot's travel distance:  28802
# Greedy Robot's travel distance:  28802

# %%
print("ValueIteration Robot's travel distance: ", mdp_result_policy_results_training[1])
# Out:
# ValueIteration Robot's travel distance:  [('red', 'empty', 'empty', 'empty', 'store_red'), ('red', 'red', 'empty', 'empty', 'store_red'), ('red', 'red', 'red', 'empty', 'store_red'), ('red', 'red', 'red', 'white', 'store_white'), ('empty', 'red', 'red', 'white', 'restore_red'), ('empty', 'empty', 'red', 'white', 'restore_red'), ('empty', 'empty', 'empty', 'white', 'restore_red'), ('empty', 'empty', 'empty', 'empty', 'restore_white'), ('blue', 'empty', 'empty', 'empty', 'store_blue'), ('blue', 'blue', 'empty', 'empty', 'store_blue'), ('empty', 'blue', 'empty', 'empty', 'restore_blue'), ('red', 'blue', 'empty', 'empty', 'store_red'), ('red', 'blue', 'white', 'empty', 'store_white'), ('red', 'blue', 'empty', 'empty', 'restore_white'), ('red', 'blue', 'red', 'empty', 'store_red'), ('empty', 'blue', 'red', 'empty', 'restore_red'), ('empty', 'blue', 'empty', 'empty', 'restore_red'), ('empty', 'empty', 'empty', 'empty', 'restore_blue'), ('blue', 'empty', 'empty', 'empty', 'store_blue'), ('blue', 'blue', 'empty', 'empty', 'store_blue'), ('blue', 'blue', 'blue', 'empty', 'store_blue'), ('blue', 'blue', 'blue', 'white', 'store_white'), ('empty', 'blue', 'blue', 'white', 'restore_blue'), ('empty', 'empty', 'blue', 'white', 'restore_blue'), ('empty', 'empty', 'blue', 'empty', 'restore_white'), ('blue', 'empty', 'blue', 'empty', 'store_blue'), ('blue', 'blue', 'blue', 'empty', 'store_blue'), ('empty', 'blue', 'blue', 'empty', 'restore_blue'), ('empty', 'empty', 'blue', 'empty', 'restore_blue'), ('red', 'empty', 'blue', 'empty', 'store_red'), ('empty', 'empty', 'blue', 'empty', 'restore_red'), ('blue', 'empty', 'blue', 'empty', 'store_blue'), ('blue', 'blue', 'blue', 'empty', 'store_blue'), ('empty', 'blue', 'blue', 'empty', 'restore_blue'), ('red', 'blue', 'blue', 'empty', 'store_red'), ('red', 'empty', 'blue', 'empty', 'restore_blue'), ('red', 'empty', 'empty', 'empty', 'restore_blue'), ('empty', 'empty', 'empty', 'empty', 'restore_red'), ('red', 'empty', 'empty', 'empty', 'store_red'), ('red', 'red', 'empty', 'empty', 'store_red'), ('red', 'red', 'red', 'empty', 'store_red'), ('empty', 'red', 'red', 'empty', 'restore_red'), ('empty', 'empty', 'red', 'empty', 'restore_red'), ('red', 'empty', 'red', 'empty', 'store_red'), ('red', 'red', 'red', 'empty', 'store_red'), ('empty', 'red', 'red', 'empty', 'restore_red'), ('empty', 'empty', 'red', 'empty', 'restore_red'), ('empty', 'empty', 'empty', 'empty', 'restore_red'), ('red', 'empty', 'empty', 'empty', 'store_red'), ('red', 'red', 'empty', 'empty', 'store_red'), ('red', 'red', 'white', 'empty', 'store_white'), ('red', 'red', 'white', 'red', 'store_red'), ('red', 'red', 'empty', 'red', 'restore_white'), ('empty', 'red', 'empty', 'red', 'restore_red'), ('empty', 'empty', 'empty', 'red', 'restore_red'), ('empty', 'empty', 'empty', 'empty', 'restore_red'), ('red', 'empty', 'empty', 'empty', 'store_red'), ('red', 'white', 'empty', 'empty', 'store_white'), ('red', 'white', 'blue', 'empty', 'store_blue'), ('red', 'white', 'blue', 'white', 'store_white'), ('red', 'empty', 'blue', 'white', 'restore_white'), ('red', 'red', 'blue', 'white', 'store_red'), ('red', 'red', 'blue', 'empty', 'restore_white'), ('empty', 'red', 'blue', 'empty', 'restore_red'), ('empty', 'empty', 'blue', 'empty', 'restore_red'), ('red', 'empty', 'blue', 'empty', 'store_red'), ('red', 'empty', 'empty', 'empty', 'restore_blue'), ('empty', 'empty', 'empty', 'empty', 'restore_red'), ('blue', 'empty', 'empty', 'empty', 'store_blue'), ('empty', 'empty', 'empty', 'empty', 'restore_blue'), ('red', 'empty', 'empty', 'empty', 'store_red'), ('red', 'red', 'empty', 'empty', 'store_red'), ('red', 'red', 'red', 'empty', 'store_red'), ('empty', 'red', 'red', 'empty', 'restore_red'), ('blue', 'red', 'red', 'empty', 'store_blue'), ('blue', 'red', 'red', 'red', 'store_red'), ('empty', 'red', 'red', 'red', 'restore_blue'), ('empty', 'empty', 'red', 'red', 'restore_red'), ('empty', 'empty', 'empty', 'red', 'restore_red'), ('empty', 'empty', 'empty ...

# %% [markdown]
# #### Evaluation on test data set

# %%
mdp_result_policy_results_order = evaluate_performance(mdpPolicy.policy, warehouse_order)
mdp_result_value_results_order = evaluate_performance(mdpValue.policy, warehouse_order)

# %%
print("ValueIteration Robot's travel distance: ", mdp_result_policy_results_order[0])
value_iter_states = mdp_result_policy_results_order[1]
print("PolicyIteration Robot's travel distance: ", mdp_result_value_results_order[0])
policy_iter_states = mdp_result_value_results_order[1]
print("Greedy Robot's travel distance: ", greedy_distance(warehouse_order)[0])
# Out:
# ValueIteration Robot's travel distance:  228
# PolicyIteration Robot's travel distance:  228
# Greedy Robot's travel distance:  228

# %% [markdown]
# ### Evaluation of training and order data set

# %%
print("Warehousetraining 2x2: ")
print("PolicyIteration Robot's travel distance: ", mdp_result_policy_results_training[0])
print("ValueIteration Robot's travel distance: ", mdp_result_value_results_training[0])
print("Greedy Robot's travel distance: ", greedy_distance(warehouse_training)[0])
print("\n")
print("Warehouseorder 2x2: ")
print("PolicyIteration Robot's travel distance: ", mdp_result_policy_results_order[0])
value_iter_states = mdp_result_policy_results_order[1]
print("ValueIteration Robot's travel distance: ", mdp_result_value_results_order[0])
policy_iter_states = mdp_result_value_results_order[1]
print("Greedy Robot's travel distance: ", greedy_distance(warehouse_order)[0])
# Out:
# Warehousetraining 2x2:
# PolicyIteration Robot's travel distance:  28802
# ValueIteration Robot's travel distance:  28802
# Greedy Robot's travel distance:  28802
#
#
# Warehouseorder 2x2:
# PolicyIteration Robot's travel distance:  228
# ValueIteration Robot's travel distance:  228
# Greedy Robot's travel distance:  228

# %%
print("Greedy Robot's policy: ", greedy_distance(warehouse_order)[1][0:14])
print("\n")
print("PolicyIteration Robot's policy: ", mdp_result_policy_results_order[1])
# Out:
# Greedy Robot's policy:  [('red', 'empty', 'empty', 'empty', 'store', 'red'), ('red', 'white', 'empty', 'empty', 'store', 'white'), ('red', 'empty', 'empty', 'empty', 'restore', 'white'), ('red', 'red', 'empty', 'empty', 'store', 'red'), ('red', 'red', 'blue', 'empty', 'store', 'blue'), ('red', 'red', 'blue', 'red', 'store', 'red'), ('empty', 'red', 'blue', 'red', 'restore', 'red'), ('empty', 'empty', 'blue', 'red', 'restore', 'red'), ('empty', 'empty', 'blue', 'empty', 'restore', 'red'), ('red', 'empty', 'blue', 'empty', 'store', 'red'), ('red', 'empty', 'empty', 'empty', 'restore', 'blue'), ('empty', 'empty', 'empty', 'empty', 'restore', 'red'), ('blue', 'empty', 'empty', 'empty', 'store', 'blue'), ('empty', 'empty', 'empty', 'empty', 'restore', 'blue')]
#
#
# PolicyIteration Robot's policy:  [('red', 'empty', 'empty', 'empty', 'store_red'), ('red', 'white', 'empty', 'empty', 'store_white'), ('red', 'empty', 'empty', 'empty', 'restore_white'), ('red', 'red', 'empty', 'empty', 'store_red'), ('red', 'red', 'blue', 'empty', 'store_blue'), ('red', 'red', 'blue', 'red', 'store_red'), ('empty', 'red', 'blue', 'red', 'restore_red'), ('empty', 'empty', 'blue', 'red', 'restore_red'), ('empty', 'empty', 'blue', 'empty', 'restore_red'), ('red', 'empty', 'blue', 'empty', 'store_red'), ('red', 'empty', 'empty', 'empty', 'restore_blue'), ('empty', 'empty', 'empty', 'empty', 'restore_red'), ('blue', 'empty', 'empty', 'empty', 'store_blue'), ('empty', 'empty', 'empty', 'empty', 'restore_blue'), ('red', 'empty', 'empty', 'empty', 'store_red'), ('red', 'red', 'empty', 'empty', 'store_red'), ('red', 'red', 'blue', 'empty', 'store_blue'), ('red', 'red', 'empty', 'empty', 'restore_blue'), ('empty', 'red', 'empty', 'empty', 'restore_red'), ('red', 'red', 'empty', 'empty', 'store_red'), ('red', 'red', 'blue', 'empty', 'store_blue'), ('red', 'red', 'empty', 'empty', 'restore_blue'), ('empty', 'red', 'empty', 'empty', 'restore_red'), ('blue', 'red', 'empty', 'empty', 'store_blue'), ('blue', 'red', 'white', 'empty', 'store_white'), ('blue', 'red', 'white', 'red', 'store_red'), ('blue', 'empty', 'white', 'red', 'restore_red'), ('blue', 'empty', 'white', 'empty', 'restore_red'), ('empty', 'empty', 'white', 'empty', 'restore_blue'), ('red', 'empty', 'white', 'empty', 'store_red'), ('empty', 'empty', 'white', 'empty', 'restore_red'), ('white', 'empty', 'white', 'empty', 'store_white'), ('white', 'red', 'white', 'empty', 'store_red'), ('white', 'red', 'white', 'red', 'store_red'), ('white', 'empty', 'white', 'red', 'restore_red'), ('white', 'red', 'white', 'red', 'store_red'), ('white', 'empty', 'white', 'red', 'restore_red'), ('white', 'empty', 'white', 'empty', 'restore_red'), ('empty', 'empty', 'white', 'empty', 'restore_white'), ('empty', 'empty', 'empty', 'empty', 'restore_white'), ('blue', 'empty', 'empty', 'empty', 'store_blue'), ('blue', 'white', 'empty', 'empty', 'store_white'), ('blue', 'white', 'blue', 'empty', 'store_blue'), ('blue', 'empty', 'blue', 'empty', 'restore_white'), ('empty', 'empty', 'blue', 'empty', 'restore_blue'), ('empty', 'empty', 'empty', 'empty', 'restore_blue'), ('white', 'empty', 'empty', 'empty', 'store_white'), ('white', 'red', 'empty', 'empty', 'store_red'), ('white', 'red', 'red', 'empty', 'store_red'), ('white', 'red', 'red', 'red', 'store_red'), ('white', 'empty', 'red', 'red', 'restore_red'), ('empty', 'empty', 'red', 'red', 'restore_white'), ('empty', 'empty', 'empty', 'red', 'restore_red'), ('empty', 'empty', 'empty', 'empty', 'restore_red'), ('white', 'empty', 'empty', 'empty', 'store_white'), ('empty', 'empty', 'empty', 'empty', 'restore_white'), ('white', 'empty', 'empty', 'empty', 'store_white'), ('white', 'white', 'empty', 'empty', 'store_white'), ('white', 'white', 'blue', 'empty', 'store_blue'), ('white', 'white', 'blue', 'white', 'store_white'), ('white', 'white', 'empty', 'white', 'restore_blue'), ('empty', 'white', 'empty', 'white', 'restore_white'), ('empty', 'empty', 'empty', 'white', 'restore_white'), ('white', 'empty', 'empty', 'white', 'store_white'), ('white', 'red', 'empty', 'white', 'store_red')]

# %% [markdown]
# ## Literature

# %% [markdown]
# [1] https://www.youtube.com/watch?v=FgzM3zpZ55o&list=PLoROMvodv4rOSOPzutgyCTapiGlY2Nd8u
